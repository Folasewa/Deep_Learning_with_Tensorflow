# %% [markdown]
# <a href="https://colab.research.google.com/github/Folasewa/Deep_Learning_with_Tensorflow/blob/main/MLP_%26_CNN_Folasewa_B02294068.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center><b>Machine Learning and Neural Networks course</b></center></h1>
# <h3><center>Exercise 3</center></h3>

# %% [markdown]
# *Your* Name:
# <font color='red'>
# Folasewa Abdulsalam, B02294068
# </font>

# %% [markdown]
# **Instructions:**
# - Create a copy of this notebook and implement your code in it.
# - Make sure you don't leave empty cells or empty answers. The code has to be clean and clearly commented
# - You should not change the code we provided you.
# - When you finish the assignment, download this **notebook** and the ***predictions.txt*** files. Grades will be based on both files! Submit both to the Moodle system. To Download the notebook go to "File" -> "Download .ipynb".
# - **Submit deadline: 03/01/2025**

# %% [markdown]
# ## Part 1 - Neural Network using NumPy

# %% [markdown]
# In this part we learn to:
# 1. Load and preprocess datasets.
# 2. Implement and train a neural network (multi-layer perceptron) for handwriting recognition (MNIST dataset), using numpy library only.

# %% [markdown]
# ### **1. Dataset**

# %% [markdown]
# Import useful packages

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml

# %% [markdown]
# Download the MNIST dataset

# %%
X, y = fetch_openml('mnist_784', return_X_y=True, as_frame=False)
print(X.shape, y.shape)
# Out:
# (70000, 784) (70000,)

# %% [markdown]
# Data normalization

# %%
## TODO: Normalize the dataset according to Min-Max normalization.
def min_max_norm(X):
    return X / 255.0  # Normalize pixel values to the range [0, 1]

X = min_max_norm(X)

# %% [markdown]
# Split the data into Train set and Test set

# %%
## TODO: Split the data into Train set and Test set (The use of libraries other than Numpy is strictly prohibited)

split_index = int(0.8 * len(X))  # 80% for training, 20% for testing
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# %% [markdown]
# Activation function

# %%
## Here you should Implement the sigmoid activation function and its derivative
def sigmoid(z):
    return 1 / (1 + np.exp(-z))  # Sigmoid activation

def sigmoid_derivative(z):
    return sigmoid(z) * (1 - sigmoid(z))  # Derivative of sigmoid

# %% [markdown]
# Softmax function

# %%
## Here you should Implement the softmax function
def softmax(z):
    exp_z = np.exp(z - np.max(z))  # Subtract max for numerical stability
    return exp_z / np.sum(exp_z, axis=0, keepdims=True)  # Normalize

# %% [markdown]
# Loss function

# %%
## Negative Log Likelihood loss function for the multiclass
def nll_loss(y_pred, y):
    loss = -np.sum(y * np.log(y_pred + 1e-8))  # Add epsilon for numerical stability
    return loss / float(y_pred.shape[1])  # Average over samples

# %% [markdown]
# Hyper-Parameters

# %%
## Here you should define the main hyper-parameters we discussed about at class.


input_size = 784  # MNIST images are 28x28
hidden_units = 128  # Number of hidden neurons
output_classes = 10  # Number of output classes for MNIST digits
num_of_epochs = 10  # Number of training epochs
learning_rate = 0.01  # Learning rate for gradient descent

# %% [markdown]
# Parameters initialization

# %%
## Here you should initialize the parameters.
## Note that the MNIST dataset has 10 classes.

W1 = np.random.randn(hidden_units, input_size) * 0.01  # Initialize weights for input to hidden layer
b1 = np.zeros((hidden_units, 1))  # Initialize biases for hidden layer
W2 = np.random.randn(output_classes, hidden_units) * 0.01  # Initialize weights for hidden to output layer
b2 = np.zeros((output_classes, 1))  # Initialize biases for output layer

# %% [markdown]
# ### **2. Training**

# %%
def train(X, y, num_of_epochs, W1, b1, W2, b2, learning_rate):
    train_size = X.shape[1]

    for epoch in range(num_of_epochs):
        avg_epoch_loss = 0
        for i in range(train_size):
            # Forward propagation
            z1 = W1.dot(X[:, i].reshape(-1, 1)) + b1
            h1 = sigmoid(z1)
            z2 = W2.dot(h1) + b2
            y_hat = softmax(z2)

            # Define y_true
            y_true = np.zeros((output_classes, 1))  # Create a one-hot encoded vector
            y_true[int(y[i])] = 1  # Set the true class index to 1

            # Compute loss
            loss = nll_loss(y_hat, y_true)
            avg_epoch_loss += loss

            # Back propagation
            dZ2 = y_hat - y_true  # Gradient for output layer
            dW2 = dZ2.dot(h1.T)
            db2 = np.sum(dZ2, axis=1, keepdims=True)

            dZ1 = W2.T.dot(dZ2) * sigmoid_derivative(z1)
            dW1 = dZ1.dot(X[:, i].reshape(-1, 1).T)
            db1 = np.sum(dZ1, axis=1, keepdims=True)

            # Update weights
            W2 -= learning_rate * dW2
            b2 -= learning_rate * db2
            W1 -= learning_rate * dW1
            b1 -= learning_rate * db1

        avg_epoch_loss /= train_size
        print("Epoch:", epoch + 1, "Loss:", avg_epoch_loss)

    return W1, b1, W2, b2

# %% [markdown]
# ### **3. Test**

# %% [markdown]
# Here you should test your model

# %%
def test(X, y):
    true_pred_counter = 0
    test_size = X.shape[1]

    for i in range(test_size):
        # Forward propagation
        z1 = W1.dot(X[:, i].reshape(-1, 1)) + b1
        h1 = sigmoid(z1)
        z2 = W2.dot(h1) + b2
        y_hat = softmax(z2)

        # Predicted class
        predicted_class = np.argmax(y_hat)  # Index of the highest probability
        true_class = int(y[i])

        # Debugging: Print predictions and true labels
        print(f"Sample {i}: Predicted = {predicted_class}, True = {true_class}")

        # Check if the prediction is correct
        if predicted_class == true_class:
            true_pred_counter += 1

    # Compute accuracy
    accuracy = true_pred_counter / test_size
    print(f"Correct Predictions: {true_pred_counter}, Total Test Samples: {test_size}")
    return accuracy

# %% [markdown]
# ### **4. Main**

# %%
W1, b1, W2, b2 = train(X_train.T, y_train, num_of_epochs, W1, b1, W2, b2, learning_rate)
  # Transpose X_train for column-based operations
test_accuracy = test(X_test.T, y_test)  # Transpose X_test for column-based operations

print("Test Accuracy:", test_accuracy)
# Out:
# Streaming output truncated to the last 5000 lines.
# Sample 9002: Predicted = 9, True = 9
# Sample 9003: Predicted = 8, True = 8
# Sample 9004: Predicted = 4, True = 4
# Sample 9005: Predicted = 1, True = 1
# Sample 9006: Predicted = 0, True = 0
# Sample 9007: Predicted = 6, True = 6
# Sample 9008: Predicted = 0, True = 0
# Sample 9009: Predicted = 9, True = 9
# Sample 9010: Predicted = 6, True = 6
# Sample 9011: Predicted = 8, True = 8
# Sample 9012: Predicted = 6, True = 6
# Sample 9013: Predicted = 1, True = 1
# Sample 9014: Predicted = 1, True = 1
# Sample 9015: Predicted = 9, True = 9
# Sample 9016: Predicted = 8, True = 8
# Sample 9017: Predicted = 9, True = 9
# Sample 9018: Predicted = 2, True = 2
# Sample 9019: Predicted = 3, True = 3
# Sample 9020: Predicted = 5, True = 5
# Sample 9021: Predicted = 5, True = 5
# Sample 9022: Predicted = 9, True = 9
# Sample 9023: Predicted = 4, True = 4
# Sample 9024: Predicted = 2, True = 2
# Sample 9025: Predicted = 1, True = 1
# Sample 9026: Predicted = 9, True = 9
# Sample 9027: Predicted = 4, True = 4
# Sample 9028: Predicted = 3, True = 3
# Sample 9029: Predicted = 9, True = 9
# Sample 9030: Predicted = 6, True = 6
# Sample 9031: Predicted = 0, True = 0
# Sample 9032: Predicted = 4, True = 4
# Sample 9033: Predicted = 0, True = 0
# Sample 9034: Predicted = 6, True = 6
# Sample 9035: Predicted = 0, True = 0
# Sample 9036: Predicted = 1, True = 1
# Sample 9037: Predicted = 2, True = 2
# Sample 9038: Predicted = 3, True = 3
# Sample 9039: Predicted = 4, True = 4
# Sample 9040: Predicted = 7, True = 7
# Sample 9041: Predicted = 8, True = 8
# Sample 9042: Predicted = 9, True = 9
# Sample 9043: Predicted = 0, True = 0
# Sample 9044: Predicted = 1, True = 1
# Sample 9045: Predicted = 2, True = 2
# Sample 9046: Predicted = 3, True = 3
# Sample 9047: Predicted = 4, True = 4
# Sample 9048: Predicted = 7, True = 7
# Sample 9049: Predicted = 8, True = 8
# Sample 9050: Predicted = 9, True = 9
# Sample 9051: Predicted = 0, True = 0
# Sample 9052: Predicted = 1, True = 1
# Sample 9053: Predicted = 2, True = 2
# Sample 9054: Predicted = 3, True = 3
# Sample 9055: Predicted = 4, True = 4
# Sample 9056: Predicted = 5, True = 5
# Sample 9057: Predicted = 6, True = 6
# Sample 9058: Predicted = 7, True = 7
# Sample 9059: Predicted = 8, True = 8
# Sample 9060: Predicted = 9, True = 9
# Sample 9061: Predicted = 8, True = 8
# Sample 9062: Predicted = 3, True = 3
# Sample 9063: Predicted = 4, True = 4
# Sample 9064: Predicted = 7, True = 7
# Sample 9065: Predicted = 8, True = 8
# Sample 9066: Predicted = 6, True = 6
# Sample 9067: Predicted = 3, True = 3
# Sample 9068: Predicted = 4, True = 4
# Sample 9069: Predicted = 0, True = 0
# Sample 9070: Predicted = 9, True = 9
# Sample 9071: Predicted = 7, True = 7
# Sample 9072: Predicted = 1, True = 1
# Sample 9073: Predicted = 9, True = 9
# Sample 9074: Predicted = 3, True = 3
# Sample 9075: Predicted = 8, True = 8
# Sample 9076: Predicted = 4, True = 4
# Sample 9077: Predicted = 7, True = 7
# Sample 9078: Predicted = 3, True = 3
# Sample 9079: Predicted = 0, True = 0
# Sample 9080: Predicted = 9, True = 9
# Sample 9081: Predicted = 1, True = 1
# Sample 9082: Predicted = 4, True = 4
# Sample 9083: Predicted = 5, True = 5
# Sample 9084: Predicted = 4, True = 4
# Sample 9085: Predicted = 6, True = 6
# Sample 9086: Predicted = 2, True = 2
# Sample 9087: Predicted = 0, True = 0
# Sample 9088: Predicted = 6, True = 6
# Sample 9089: Predicted = 2, True = 2
# Sample 9090: Predicted = 1, True = 1
# Sample 9091: Predicted = 1, True = 1
# Sample 9092: Predicted = 1, True = 1
# Sample 9093: Predicted = 1, True = 1
# Sample 9094: Predicted = 7, True = 7
# Sample 9095: Predicted = 2, True = 2
# Sample 9096: Predicted = 4, True = 4
# Sample 9097: Predicted = 7, True = 7
# Sample 9098: Predicted = 5, True = 5
# Sample 9099: Predicted = 2, True = 2
# Sample 9100: Predicted = 9, True = 9
# Sample 9101: Predicted = 4, True = 4
# Sample 9102: Predicted = 5, True = 5
# Sample 9103: Predicted = 8, True = 8
# Sample 9104: Predicted = 4, True = 4
# Sample 9105: Predicted = 2, True = 2
# Sample 9106: Predicted = 9, True = 9
# Sample 9107: Predicted = 7, True = 7
# Sample 9108: Predicted = 0, True = 0
# Sample 9109: Predicted = 0, True = 0
# Sample 9110: Predicted = 7, True = 7
# Sample 9111: Predicted = 5, True = 5
# Sample 9112: Predicted = 1, True = 1
# Sample 9113: Predicted = 1, True = 1
# Sample 9114: Predicted = 7, True = 7
# Sample 9115: Predicted = 6, True = 6
# Sample 9116: Predicted = 6, True = 6
# Sample 9117: Predicted = 6, True = 6
# Sample 9118: Predicted = 8, True = 8
# Sample 9119: Predicted = 2, True = 2
# Sample 9120: Predicted = 2, True = 2
# Sample 9121: Predicted = 7, True = 7
# Sample 9122: Predicted = 7, True = 7
# Sample 9123: Predicted = 4, True = 4
# Sample 9124: Predicted = 0, True = 0
# Sample 9125: Predicted = 2, True = 2
# Sample 9126: Predicted = 4, True = 4
# Sample 9127: Predicted = 2, True = 2
# Sample 9128: Predicted = 1, True = 1
# Sample 9129: Predicted = 8, True = 8
# Sample 9130: Predicted = 9, True = 9
# Sample 9131: Predicted = 6, True = 6
# Sample 9132: Predicted = 1, True = 1
# Sample 9133: Predicted = 0, True = 0
# Sample 9134: Predicted = 5, True = 5
# Sample 9135: Predicted = 9, True = 9
# Sample 9136: Predicted = 6, True = 6
# Sample 9137: Predicted = 9, True = 9
# Sample 9138: Predicted = 8, True = 8
# Sample 9139: Predicted = 0, True = 0
# Sample 9140: Predicted = 3, True = 3
# Sample 9141: Predicted = 0, True = 0
# Sample 9142: Predicted = 8, True = 8
# Sample 9143: Predicted = 3, True = 3
# Sample 9144: Predicted = 9, True = 9
# Sample 9145: Predicted = 6, True = 6
# Sample 9146: Predicted = 3, True = 3
# Sample 9147: Predicted = 0, True = 0
# Sample 9148: Predicted = 1, True = 1
# Sample 9149: Predicted = 2, True = 2
# Sample 9150: Predicted = 3, True = 3
# Sample 9151: Predicted = 4, True = 4
# Sample 9152: Predicted = 5, True = 5
# Sample 9153: Predicted = 6, True = 6
# Sample 9154: Predicted = 7, True = 7
# Sample 9155: Predicted = 0, True = 0
# Sample 9156: Predicted = 1, True = 1
# Sample 9157: Predicted = 2, True = 2
# Sample 9158: Predicted = 3, True = 3
# Sample 9159: Predicted = 4, True = 4
# Sample 9160: Predicted = 5, True = 5
# Sample 9161: Predicted = 6, True = 6
# Sample 9162: Predicted = 7, True = 7
# Sample 9163: Predicted = 8, True = 8
# Sample 9164: Predicted = 9, True = 9
# Sample 9165: Predicted = 5, True = 0
# Sample 9166: Predicted = 1, True = 1
# Sample 9167: Predicted = 2, True = 2
# Sample 9168: Predicted = 3, True = 3
# Sample 9169: Predicted = 4, True = 4
# Sample 9170: Predicted = 5, True = 5
# Sample 9171: Predicted = 6, True = 6
# Sample 9172: Predicted = 7, True = 7
# Sample 9173: Predicted = 8, True = 8
# Sample 9174: Predicted = 5, True = 5
# Sample 9175: Predicted = 4, True = 4
# Sample 9176: Predicted = 8, True = 8
# Sample 9177: Predicted = 7, True = 7
# Sample 9178: Predicted = 4, True = 4
# Sample 9179: Predicted = 7, True = 7
# Sample 9180: Predicted = 7, True = 7
# Sample 9181: Predicted = 3, True = 3
# Sample 9182: Predicted = 9, True = 9
# Sample 9183: Predicted = 8, True = 8
# Sample 9184: Predicted = 8, True = 8
# Sample 9185: Predicted = 3, True = 3
# Sample 9186: Predicted = 1, True = 1
# Sample 9187: Predicted = 5, True = 5
# Sample 9188: Predicted = 8, True = 8
# Sample 9189: Predicted = 2, True = 2
# Sample 9190: Predicted = 7, True = 7
# Sample 9191: Predicted = 4, True = 4
# Sample 9192: Predicted = 2, True = 2
# Sample 9193: Predicted = 1, True = 1
# Sample 9194: Predicted = 5, True = 5
# Sample 9195: Predicted = 4, True = 4
# Sample 9196: Predicted = 5, True = 5
# Sample 9197: Predicted = 5, True = 5
# Sample 9198: Predicted = 8, True = 8
# Sample 9199: Predicted = 6, True = 6
# Sample 9200: Predicted = 4, True = 4
# Sample 9201: Predicted = 4, True = 4
# Sample 9202: Predicted = 4, True = 4
# Sample 9203: Predicted = 1, True = 1
# Sample 9204: Predicted = 8, True = 8
# Sample 9205: Predicted = 7, True = 7
# Sample 9206: Predicted = 5, True = 5
# Sample 9207: Predicted = 5, True = 5
# Sample 9208: Predicted = 1, True = 1
# Sample 9209: Predicted = 8, True = 8
# Sample 9210: Predicted = 9, True = 9
# Sample 9211: Predicted = 1, True = 1
# Sample 9212: Predicted = 3, True = 3
# Sample 9213: Predicted = 6, True = 6
# Sample 9214: Predicted = 3, True = 3
# Sample 9215: Predicted = 3, True = 3
# Sample 9216: Predicted = 2, True = 2
# Sample 9217: Predicted = 2, True = 2
# Sample 9218: Predicted = 6, True = 6
# Sample 9219: Predicted = 9, True = 9
# Sample 9220: Predicted = 9, True = 9
# Sample 9221: Predicted = 6, True = 6
# Sample 9222: Predicted = 5, True = 5
# Sample 9223: Predicted = 5, True = 5
# Sample 9224: Predicted = 3, True = 3
# Sample 9225: Predicted = 3, True = 3
# Sample 9226: Predicted = 8, True = 8
# Sample 9227: Predicted = 1, True = 1
# Sample 9228: Predicted = 6, True = 6
# Sample 9229: Predicted = 5, True = 5
# Sample 9230: Predicted = 6, True = 6
# Sample 9231: Predicted = 8, True = 8
# Sample 9232: Predicted = 1, True = 1
# Sample 9233: Predicted = 9, True = 9
# Sample 9234: Predicted = 7, True = 7
# Sample 9235: Predicted = 6, True = 6
# Sample 9236: Predicted = 8, True = 8
# Sample 9237: Predicted = 3, True = 3
# Sample 9238: Predicted = 7, True = 7
# Sample 9239: Predicted = 4, True = 4
# Sample 9240: Predicted = 7, True = 7
# Sample 9241: Predicted = 0, True = 0
# Sample 9242: Predicted = 9, True = 9
# Sample 9243: Predicted = 0, True = 0
# Sample 9244: Predicted = 0, True = 0
# Sample 9245: Predicted = 3, True = 3
# Sample 9246: Predicted = 7, True = 7
# Sample 9247: Predicted = 9, True = 9
# Sample 9248: Predicted = 3, True = 3
# Sample 9249: Predicted = 0, True = 0
# Sample 9250: Predicted = 2, True = 2
# Sample 9251: Predicted = 0, True = 0
# Sample 9252: Predicted = 1, True = 1
# Sample 9253: Predicted = 0, True = 0
# Sample 9254: Predicted = 1, True = 1
# Sample 9255: Predicted = 0, True = 0
# Sample 9256: Predicted = 4, True = 4
# Sample 9257: Predicted = 0, True = 0
# Sample 9258: Predicted = 1, True = 1
# Sample 9259: Predicted = 0, True = 0
# Sample 9260: Predicted = 4, True = 4
# Sample 9261: Predicted = 7, True = 7
# Sample 9262: Predicted = 9, True = 9
# Sample 9263: Predicted = 6, True = 6
# Sample 9264: Predicted = 2, True = 2
# Sample 9265: Predicted = 6, True = 6
# Sample 9266: Predicted = 2, True = 2
# Sample 9267: Predicted = 2, True = 2
# Sample 9268: Predicted = 9, True = 9
# Sample 9269: Predicted = 9, True = 9
# Sample 9270: Predicted = 0, True = 0
# Sample 9271: Predicted = 1, True = 1
# Sample 9272: Predicted = 2, True = 2
# Sample 9273: Predicted = 3, True = 3
# Sample 9274: Predicted = 4, True = 4
# Sample 9275: Predicted = 5, True = 5
# Sample 9276: Predicted = 6, True = 6
# Sample 9277: Predicted = 7, True = 7
# Sample 9278: Predicted = 8, True = 8
# Sample 9279: Predicted = 9, True = 9
# Sample 9280: Predicted = 0, True = 0
# Sample 9281: Predicted = 1, True = 1
# Sample 9282: Predicted = 2, True = 2
# Sample 9283: Predicted = 3, True = 3
# Sample 9284: Predicted = 4, True = 4
# Sample 9285: Predicted = 5, True = 5
# Sample 9286: Predicted = 6, True = 6
# Sample 9287: Predicted = 7, True = 7
# Sample 9288: Predicted = 8, True = 8
# Sample 9289: Predicted = 9, True = 9
# Sample 9290: Predicted = 0, True = 0
# Sample 9291: Predicted = 1, True = 1
# Sample 9292: Predicted = 2, True = 2
# Sample 9293: Predicted = 3, True = 3
# Sample 9294: Predicted = 4, True = 4
# Sample 9295: Predicted = 5, True = 5
# Sample 9296: Predicted = 6, True = 6
# Sample 9297: Predicted = 7, True = 7
# Sample 9298: Predicted = 8, True = 8
# Sample 9299: Predicted = 9, True = 9
# Sample 9300: Predicted = 8, True = 8
# Sample 9301: Predicted = 0, True = 0
# Sample 9302: Predicted = 5, True = 5
# Sample 9303: Predicted = 6, True = 6
# Sample 9304: Predicted = 6, True = 6
# Sample 9305: Predicted = 0, True = 0
# Sample 9306: Predicted = 8, True = 8
# Sample 9307: Predicted = 0, True = 0
# Sample 9308: Predicted = 2, True = 2
# Sample 9309: Predicted = 3, True = 3
# Sample 9310: Predicted = 7, True = 7
# Sample 9311: Predicted = 9, True = 9
# Sample 9312: Predicted = 4, True = 4
# Sample 9313: Predicted = 7, True = 7
# Sample 9314: Predicted = 1, True = 1
# Sample 9315: Predicted = 9, True = 9
# Sample 9316: Predicted = 1, True = 1
# Sample 9317: Predicted = 7, True = 7
# Sample 9318: Predicted = 1, True = 1
# Sample 9319: Predicted = 4, True = 4
# Sample 9320: Predicted = 0, True = 0
# Sample 9321: Predicted = 0, True = 0
# Sample 9322: Predicted = 4, True = 4
# Sample 9323: Predicted = 1, True = 1
# Sample 9324: Predicted = 7, True = 7
# Sample 9325: Predicted = 5, True = 5
# Sample 9326: Predicted = 7, True = 7
# Sample 9327: Predicted = 1, True = 1
# Sample 9328: Predicted = 3, True = 3
# Sample 9329: Predicted = 3, True = 3
# Sample 9330: Predicted = 3, True = 3
# Sample 9331: Predicted = 6, True = 1
# Sample 9332: Predicted = 6, True = 6
# Sample 9333: Predicted = 9, True = 9
# Sample 9334: Predicted = 7, True = 7
# Sample 9335: Predicted = 4, True = 4
# Sample 9336: Predicted = 3, True = 3
# Sample 9337: Predicted = 0, True = 0
# Sample 9338: Predicted = 2, True = 2
# Sample 9339: Predicted = 5, True = 5
# Sample 9340: Predicted = 2, True = 2
# Sample 9341: Predicted = 6, True = 6
# Sample 9342: Predicted = 0, True = 0
# Sample 9343: Predicted = 8, True = 8
# Sample 9344: Predicted = 9, True = 9
# Sample 9345: Predicted = 4, True = 4
# Sample 9346: Predicted = 3, True = 3
# Sample 9347: Predicted = 5, True = 5
# Sample 9348: Predicted = 4, True = 4
# Sample 9349: Predicted = 8, True = 8
# Sample 9350: Predicted = 1, True = 1
# Sample 9351: Predicted = 5, True = 5
# Sample 9352: Predicted = 9, True = 9
# Sample 9353: Predicted = 0, True = 0
# Sample 9354: Predicted = 6, True = 6
# Sample 9355: Predicted = 4, True = 4
# Sample 9356: Predicted = 3, True = 3
# Sample 9357: Predicted = 6, True = 6
# Sample 9358: Predicted = 3, True = 3
# Sample 9359: Predicted = 3, True = 3
# Sample 9360: Predicted = 8, True = 8
# Sample 9361: Predicted = 1, True = 1
# Sample 9362: Predicted = 4, True = 4
# Sample 9363: Predicted = 7, True = 7
# Sample 9364: Predicted = 5, True = 5
# Sample 9365: Predicted = 7, True = 7
# Sample 9366: Predicted = 2, True = 2
# Sample 9367: Predicted = 2, True = 2
# Sample 9368: Predicted = 0, True = 0
# Sample 9369: Predicted = 0, True = 0
# Sample 9370: Predicted = 1, True = 1
# Sample 9371: Predicted = 7, True = 7
# Sample 9372: Predicted = 7, True = 7
# Sample 9373: Predicted = 9, True = 9
# Sample 9374: Predicted = 5, True = 5
# Sample 9375: Predicted = 9, True = 9
# Sample 9376: Predicted = 8, True = 8
# Sample 9377: Predicted = 9, True = 9
# Sample 9378: Predicted = 6, True = 6
# Sample 9379: Predicted = 8, True = 8
# Sample 9380: Predicted = 8, True = 8
# Sample 9381: Predicted = 2, True = 2
# Sample 9382: Predicted = 3, True = 3
# Sample 9383: Predicted = 6, True = 6
# Sample 9384: Predicted = 1, True = 1
# Sample 9385: Predicted = 2, True = 2
# Sample 9386: Predicted = 9, True = 9
# Sample 9387: Predicted = 8, True = 8
# Sample 9388: Predicted = 9, True = 9
# Sample 9389: Predicted = 5, True = 5
# Sample 9390: Predicted = 2, True = 2
# Sample 9391: Predicted = 6, True = 6
# Sample 9392: Predicted = 2, True = 2
# Sample 9393: Predicted = 4, True = 4
# Sample 9394: Predicted = 8, True = 8
# Sample 9395: Predicted = 4, True = 4
# Sample 9396: Predicted = 6, True = 6
# Sample 9397: Predicted = 5, True = 5
# Sample 9398: Predicted = 0, True = 0
# Sample 9399: Predicted = 1, True = 1
# Sample 9400: Predicted = 5, True = 5
# Sample 9401: Predicted = 6, True = 6
# Sample 9402: Predicted = 7, True = 7
# Sample 9403: Predicted = 8, True = 8
# Sample 9404: Predicted = 9, True = 9
# Sample 9405: Predicted = 0, True = 0
# Sample 9406: Predicted = 1, True = 1
# Sample 9407: Predicted = 2, True = 2
# Sample 9408: Predicted = 3, True = 3
# Sample 9409: Predicted = 4, True = 4
# Sample 9410: Predicted = 5, True = 5
# Sample 9411: Predicted = 6, True = 6
# Sample 9412: Predicted = 7, True = 7
# Sample 9413: Predicted = 8, True = 8
# Sample 9414: Predicted = 9, True = 9
# Sample 9415: Predicted = 0, True = 0
# Sample 9416: Predicted = 1, True = 1
# Sample 9417: Predicted = 2, True = 2
# Sample 9418: Predicted = 3, True = 3
# Sample 9419: Predicted = 4, True = 4
# Sample 9420: Predicted = 5, True = 5
# Sample 9421: Predicted = 6, True = 6
# Sample 9422: Predicted = 7, True = 7
# Sample 9423: Predicted = 8, True = 8
# Sample 9424: Predicted = 9, True = 9
# Sample 9425: Predicted = 7, True = 7
# Sample 9426: Predicted = 4, True = 4
# Sample 9427: Predicted = 2, True = 2
# Sample 9428: Predicted = 0, True = 0
# Sample 9429: Predicted = 9, True = 9
# Sample 9430: Predicted = 0, True = 0
# Sample 9431: Predicted = 1, True = 1
# Sample 9432: Predicted = 5, True = 5
# Sample 9433: Predicted = 8, True = 8
# Sample 9434: Predicted = 8, True = 8
# Sample 9435: Predicted = 0, True = 0
# Sample 9436: Predicted = 2, True = 2
# Sample 9437: Predicted = 7, True = 7
# Sample 9438: Predicted = 8, True = 8
# Sample 9439: Predicted = 4, True = 4
# Sample 9440: Predicted = 4, True = 4
# Sample 9441: Predicted = 6, True = 6
# Sample 9442: Predicted = 1, True = 1
# Sample 9443: Predicted = 0, True = 0
# Sample 9444: Predicted = 4, True = 4
# Sample 9445: Predicted = 5, True = 5
# Sample 9446: Predicted = 3, True = 3
# Sample 9447: Predicted = 9, True = 9
# Sample 9448: Predicted = 4, True = 4
# Sample 9449: Predicted = 2, True = 2
# Sample 9450: Predicted = 0, True = 0
# Sample 9451: Predicted = 5, True = 5
# Sample 9452: Predicted = 0, True = 0
# Sample 9453: Predicted = 1, True = 1
# Sample 9454: Predicted = 3, True = 3
# Sample 9455: Predicted = 2, True = 2
# Sample 9456: Predicted = 9, True = 9
# Sample 9457: Predicted = 8, True = 1
# Sample 9458: Predicted = 6, True = 6
# Sample 9459: Predicted = 0, True = 0
# Sample 9460: Predicted = 1, True = 1
# Sample 9461: Predicted = 1, True = 1
# Sample 9462: Predicted = 8, True = 8
# Sample 9463: Predicted = 0, True = 0
# Sample 9464: Predicted = 4, True = 4
# Sample 9465: Predicted = 7, True = 7
# Sample 9466: Predicted = 7, True = 7
# Sample 9467: Predicted = 6, True = 6
# Sample 9468: Predicted = 3, True = 3
# Sample 9469: Predicted = 6, True = 6
# Sample 9470: Predicted = 0, True = 0
# Sample 9471: Predicted = 7, True = 7
# Sample 9472: Predicted = 3, True = 3
# Sample 9473: Predicted = 5, True = 5
# Sample 9474: Predicted = 4, True = 4
# Sample 9475: Predicted = 2, True = 2
# Sample 9476: Predicted = 4, True = 4
# Sample 9477: Predicted = 1, True = 1
# Sample 9478: Predicted = 8, True = 8
# Sample 9479: Predicted = 3, True = 3
# Sample 9480: Predicted = 5, True = 5
# Sample 9481: Predicted = 6, True = 6
# Sample 9482: Predicted = 7, True = 7
# Sample 9483: Predicted = 0, True = 0
# Sample 9484: Predicted = 6, True = 6
# Sample 9485: Predicted = 7, True = 7
# Sample 9486: Predicted = 1, True = 1
# Sample 9487: Predicted = 2, True = 2
# Sample 9488: Predicted = 5, True = 5
# Sample 9489: Predicted = 8, True = 8
# Sample 9490: Predicted = 1, True = 1
# Sample 9491: Predicted = 9, True = 9
# Sample 9492: Predicted = 3, True = 3
# Sample 9493: Predicted = 8, True = 8
# Sample 9494: Predicted = 2, True = 2
# Sample 9495: Predicted = 8, True = 8
# Sample 9496: Predicted = 7, True = 7
# Sample 9497: Predicted = 6, True = 6
# Sample 9498: Predicted = 7, True = 7
# Sample 9499: Predicted = 1, True = 1
# Sample 9500: Predicted = 4, True = 4
# Sample 9501: Predicted = 6, True = 6
# Sample 9502: Predicted = 2, True = 2
# Sample 9503: Predicted = 9, True = 9
# Sample 9504: Predicted = 3, True = 3
# Sample 9505: Predicted = 0, True = 0
# Sample 9506: Predicted = 1, True = 1
# Sample 9507: Predicted = 2, True = 2
# Sample 9508: Predicted = 3, True = 3
# Sample 9509: Predicted = 4, True = 4
# Sample 9510: Predicted = 5, True = 5
# Sample 9511: Predicted = 6, True = 6
# Sample 9512: Predicted = 7, True = 7
# Sample 9513: Predicted = 0, True = 0
# Sample 9514: Predicted = 1, True = 1
# Sample 9515: Predicted = 2, True = 2
# Sample 9516: Predicted = 3, True = 3
# Sample 9517: Predicted = 4, True = 4
# Sample 9518: Predicted = 5, True = 5
# Sample 9519: Predicted = 0, True = 0
# Sample 9520: Predicted = 1, True = 1
# Sample 9521: Predicted = 2, True = 2
# Sample 9522: Predicted = 8, True = 8
# Sample 9523: Predicted = 9, True = 9
# Sample 9524: Predicted = 1, True = 1
# Sample 9525: Predicted = 4, True = 4
# Sample 9526: Predicted = 0, True = 0
# Sample 9527: Predicted = 9, True = 9
# Sample 9528: Predicted = 5, True = 5
# Sample 9529: Predicted = 0, True = 0
# Sample 9530: Predicted = 8, True = 8
# Sample 9531: Predicted = 0, True = 0
# Sample 9532: Predicted = 7, True = 7
# Sample 9533: Predicted = 7, True = 7
# Sample 9534: Predicted = 1, True = 1
# Sample 9535: Predicted = 1, True = 1
# Sample 9536: Predicted = 2, True = 2
# Sample 9537: Predicted = 9, True = 9
# Sample 9538: Predicted = 3, True = 3
# Sample 9539: Predicted = 6, True = 6
# Sample 9540: Predicted = 7, True = 7
# Sample 9541: Predicted = 2, True = 2
# Sample 9542: Predicted = 3, True = 3
# Sample 9543: Predicted = 8, True = 8
# Sample 9544: Predicted = 1, True = 1
# Sample 9545: Predicted = 2, True = 2
# Sample 9546: Predicted = 9, True = 9
# Sample 9547: Predicted = 8, True = 8
# Sample 9548: Predicted = 8, True = 8
# Sample 9549: Predicted = 7, True = 7
# Sample 9550: Predicted = 1, True = 1
# Sample 9551: Predicted = 7, True = 7
# Sample 9552: Predicted = 1, True = 1
# Sample 9553: Predicted = 1, True = 1
# Sample 9554: Predicted = 0, True = 0
# Sample 9555: Predicted = 3, True = 3
# Sample 9556: Predicted = 4, True = 4
# Sample 9557: Predicted = 2, True = 2
# Sample 9558: Predicted = 6, True = 6
# Sample 9559: Predicted = 4, True = 4
# Sample 9560: Predicted = 7, True = 7
# Sample 9561: Predicted = 4, True = 4
# Sample 9562: Predicted = 2, True = 2
# Sample 9563: Predicted = 7, True = 7
# Sample 9564: Predicted = 4, True = 4
# Sample 9565: Predicted = 9, True = 9
# Sample 9566: Predicted = 1, True = 1
# Sample 9567: Predicted = 0, True = 0
# Sample 9568: Predicted = 6, True = 6
# Sample 9569: Predicted = 8, True = 8
# Sample 9570: Predicted = 5, True = 5
# Sample 9571: Predicted = 5, True = 5
# Sample 9572: Predicted = 5, True = 5
# Sample 9573: Predicted = 3, True = 3
# Sample 9574: Predicted = 5, True = 5
# Sample 9575: Predicted = 9, True = 9
# Sample 9576: Predicted = 7, True = 7
# Sample 9577: Predicted = 4, True = 4
# Sample 9578: Predicted = 8, True = 8
# Sample 9579: Predicted = 5, True = 5
# Sample 9580: Predicted = 9, True = 9
# Sample 9581: Predicted = 6, True = 6
# Sample 9582: Predicted = 9, True = 9
# Sample 9583: Predicted = 3, True = 3
# Sample 9584: Predicted = 0, True = 0
# Sample 9585: Predicted = 3, True = 3
# Sample 9586: Predicted = 8, True = 8
# Sample 9587: Predicted = 9, True = 9
# Sample 9588: Predicted = 1, True = 1
# Sample 9589: Predicted = 8, True = 8
# Sample 9590: Predicted = 1, True = 1
# Sample 9591: Predicted = 6, True = 6
# Sample 9592: Predicted = 0, True = 0
# Sample 9593: Predicted = 0, True = 0
# Sample 9594: Predicted = 1, True = 1
# Sample 9595: Predicted = 2, True = 2
# Sample 9596: Predicted = 3, True = 3
# Sample 9597: Predicted = 4, True = 4
# Sample 9598: Predicted = 5, True = 5
# Sample 9599: Predicted = 6, True = 6
# Sample 9600: Predicted = 9, True = 7
# Sample 9601: Predicted = 8, True = 8
# Sample 9602: Predicted = 9, True = 9
# Sample 9603: Predicted = 0, True = 0
# Sample 9604: Predicted = 1, True = 1
# Sample 9605: Predicted = 2, True = 2
# Sample 9606: Predicted = 3, True = 3
# Sample 9607: Predicted = 4, True = 4
# Sample 9608: Predicted = 5, True = 5
# Sample 9609: Predicted = 6, True = 6
# Sample 9610: Predicted = 7, True = 7
# Sample 9611: Predicted = 8, True = 8
# Sample 9612: Predicted = 9, True = 9
# Sample 9613: Predicted = 0, True = 0
# Sample 9614: Predicted = 1, True = 1
# Sample 9615: Predicted = 2, True = 2
# Sample 9616: Predicted = 3, True = 3
# Sample 9617: Predicted = 4, True = 4
# Sample 9618: Predicted = 5, True = 5
# Sample 9619: Predicted = 6, True = 6
# Sample 9620: Predicted = 7, True = 7
# Sample 9621: Predicted = 8, True = 8
# Sample 9622: Predicted = 9, True = 9
# Sample 9623: Predicted = 3, True = 3
# Sample 9624: Predicted = 5, True = 5
# Sample 9625: Predicted = 3, True = 3
# Sample 9626: Predicted = 2, True = 2
# Sample 9627: Predicted = 9, True = 9
# Sample 9628: Predicted = 3, True = 3
# Sample 9629: Predicted = 2, True = 2
# Sample 9630: Predicted = 1, True = 1
# Sample 9631: Predicted = 4, True = 4
# Sample 9632: Predicted = 5, True = 5
# Sample 9633: Predicted = 5, True = 5
# Sample 9634: Predicted = 3, True = 2
# Sample 9635: Predicted = 3, True = 3
# Sample 9636: Predicted = 2, True = 2
# Sample 9637: Predicted = 1, True = 1
# Sample 9638: Predicted = 3, True = 3
# Sample 9639: Predicted = 9, True = 9
# Sample 9640: Predicted = 7, True = 7
# Sample 9641: Predicted = 2, True = 2
# Sample 9642: Predicted = 5, True = 1
# Sample 9643: Predicted = 2, True = 2
# Sample 9644: Predicted = 8, True = 8
# Sample 9645: Predicted = 9, True = 9
# Sample 9646: Predicted = 1, True = 1
# Sample 9647: Predicted = 8, True = 8
# Sample 9648: Predicted = 8, True = 8
# Sample 9649: Predicted = 7, True = 7
# Sample 9650: Predicted = 8, True = 8
# Sample 9651: Predicted = 1, True = 1
# Sample 9652: Predicted = 0, True = 0
# Sample 9653: Predicted = 0, True = 0
# Sample 9654: Predicted = 7, True = 7
# Sample 9655: Predicted = 7, True = 7
# Sample 9656: Predicted = 8, True = 8
# Sample 9657: Predicted = 7, True = 7
# Sample 9658: Predicted = 5, True = 5
# Sample 9659: Predicted = 0, True = 0
# Sample 9660: Predicted = 6, True = 6
# Sample 9661: Predicted = 1, True = 1
# Sample 9662: Predicted = 5, True = 5
# Sample 9663: Predicted = 7, True = 7
# Sample 9664: Predicted = 4, True = 4
# Sample 9665: Predicted = 6, True = 6
# Sample 9666: Predicted = 1, True = 1
# Sample 9667: Predicted = 2, True = 2
# Sample 9668: Predicted = 5, True = 5
# Sample 9669: Predicted = 0, True = 0
# Sample 9670: Predicted = 7, True = 7
# Sample 9671: Predicted = 9, True = 9
# Sample 9672: Predicted = 9, True = 9
# Sample 9673: Predicted = 0, True = 0
# Sample 9674: Predicted = 3, True = 3
# Sample 9675: Predicted = 8, True = 8
# Sample 9676: Predicted = 7, True = 4
# Sample 9677: Predicted = 4, True = 4
# Sample 9678: Predicted = 8, True = 8
# Sample 9679: Predicted = 1, True = 1
# Sample 9680: Predicted = 8, True = 8
# Sample 9681: Predicted = 6, True = 6
# Sample 9682: Predicted = 5, True = 5
# Sample 9683: Predicted = 9, True = 9
# Sample 9684: Predicted = 0, True = 0
# Sample 9685: Predicted = 0, True = 0
# Sample 9686: Predicted = 0, True = 0
# Sample 9687: Predicted = 3, True = 3
# Sample 9688: Predicted = 7, True = 7
# Sample 9689: Predicted = 1, True = 1
# Sample 9690: Predicted = 6, True = 6
# Sample 9691: Predicted = 4, True = 4
# Sample 9692: Predicted = 2, True = 2
# Sample 9693: Predicted = 6, True = 6
# Sample 9694: Predicted = 6, True = 6
# Sample 9695: Predicted = 0, True = 0
# Sample 9696: Predicted = 4, True = 4
# Sample 9697: Predicted = 5, True = 5
# Sample 9698: Predicted = 4, True = 4
# Sample 9699: Predicted = 1, True = 1
# Sample 9700: Predicted = 3, True = 3
# Sample 9701: Predicted = 8, True = 8
# Sample 9702: Predicted = 6, True = 6
# Sample 9703: Predicted = 3, True = 3
# Sample 9704: Predicted = 9, True = 9
# Sample 9705: Predicted = 9, True = 9
# Sample 9706: Predicted = 5, True = 5
# Sample 9707: Predicted = 9, True = 9
# Sample 9708: Predicted = 3, True = 3
# Sample 9709: Predicted = 7, True = 7
# Sample 9710: Predicted = 8, True = 8
# Sample 9711: Predicted = 5, True = 5
# Sample 9712: Predicted = 6, True = 6
# Sample 9713: Predicted = 4, True = 4
# Sample 9714: Predicted = 7, True = 7
# Sample 9715: Predicted = 6, True = 6
# Sample 9716: Predicted = 2, True = 2
# Sample 9717: Predicted = 2, True = 2
# Sample 9718: Predicted = 0, True = 0
# Sample 9719: Predicted = 9, True = 9
# Sample 9720: Predicted = 4, True = 4
# Sample 9721: Predicted = 0, True = 0
# Sample 9722: Predicted = 1, True = 1
# Sample 9723: Predicted = 2, True = 2
# Sample 9724: Predicted = 3, True = 3
# Sample 9725: Predicted = 4, True = 4
# Sample 9726: Predicted = 5, True = 5
# Sample 9727: Predicted = 6, True = 6
# Sample 9728: Predicted = 7, True = 7
# Sample 9729: Predicted = 8, True = 8
# Sample 9730: Predicted = 9, True = 9
# Sample 9731: Predicted = 0, True = 0
# Sample 9732: Predicted = 1, True = 1
# Sample 9733: Predicted = 2, True = 2
# Sample 9734: Predicted = 7, True = 3
# Sample 9735: Predicted = 5, True = 5
# Sample 9736: Predicted = 6, True = 6
# Sample 9737: Predicted = 0, True = 0
# Sample 9738: Predicted = 1, True = 1
# Sample 9739: Predicted = 2, True = 2
# Sample 9740: Predicted = 3, True = 3
# Sample 9741: Predicted = 4, True = 4
# Sample 9742: Predicted = 5, True = 5
# Sample 9743: Predicted = 6, True = 6
# Sample 9744: Predicted = 8, True = 8
# Sample 9745: Predicted = 7, True = 7
# Sample 9746: Predicted = 1, True = 1
# Sample 9747: Predicted = 3, True = 3
# Sample 9748: Predicted = 2, True = 2
# Sample 9749: Predicted = 2, True = 8
# Sample 9750: Predicted = 0, True = 0
# Sample 9751: Predicted = 7, True = 7
# Sample 9752: Predicted = 5, True = 5
# Sample 9753: Predicted = 9, True = 9
# Sample 9754: Predicted = 9, True = 9
# Sample 9755: Predicted = 6, True = 6
# Sample 9756: Predicted = 0, True = 0
# Sample 9757: Predicted = 7, True = 9
# Sample 9758: Predicted = 4, True = 4
# Sample 9759: Predicted = 1, True = 1
# Sample 9760: Predicted = 3, True = 3
# Sample 9761: Predicted = 2, True = 2
# Sample 9762: Predicted = 1, True = 1
# Sample 9763: Predicted = 2, True = 2
# Sample 9764: Predicted = 3, True = 3
# Sample 9765: Predicted = 8, True = 8
# Sample 9766: Predicted = 3, True = 3
# Sample 9767: Predicted = 2, True = 2
# Sample 9768: Predicted = 6, True = 6
# Sample 9769: Predicted = 5, True = 5
# Sample 9770: Predicted = 6, True = 6
# Sample 9771: Predicted = 8, True = 8
# Sample 9772: Predicted = 2, True = 2
# Sample 9773: Predicted = 7, True = 7
# Sample 9774: Predicted = 4, True = 4
# Sample 9775: Predicted = 8, True = 8
# Sample 9776: Predicted = 1, True = 1
# Sample 9777: Predicted = 8, True = 8
# Sample 9778: Predicted = 0, True = 0
# Sample 9779: Predicted = 5, True = 5
# Sample 9780: Predicted = 3, True = 3
# Sample 9781: Predicted = 9, True = 9
# Sample 9782: Predicted = 4, True = 4
# Sample 9783: Predicted = 1, True = 1
# Sample 9784: Predicted = 9, True = 9
# Sample 9785: Predicted = 2, True = 2
# Sample 9786: Predicted = 1, True = 1
# Sample 9787: Predicted = 9, True = 9
# Sample 9788: Predicted = 6, True = 6
# Sample 9789: Predicted = 7, True = 7
# Sample 9790: Predicted = 9, True = 9
# Sample 9791: Predicted = 0, True = 0
# Sample 9792: Predicted = 4, True = 4
# Sample 9793: Predicted = 6, True = 6
# Sample 9794: Predicted = 1, True = 1
# Sample 9795: Predicted = 7, True = 7
# Sample 9796: Predicted = 3, True = 3
# Sample 9797: Predicted = 8, True = 8
# Sample 9798: Predicted = 7, True = 7
# Sample 9799: Predicted = 2, True = 2
# Sample 9800: Predicted = 9, True = 9
# Sample 9801: Predicted = 6, True = 6
# Sample 9802: Predicted = 5, True = 5
# Sample 9803: Predicted = 8, True = 8
# Sample 9804: Predicted = 3, True = 3
# Sample 9805: Predicted = 9, True = 9
# Sample 9806: Predicted = 0, True = 0
# Sample 9807: Predicted = 5, True = 5
# Sample 9808: Predicted = 7, True = 7
# Sample 9809: Predicted = 1, True = 1
# Sample 9810: Predicted = 6, True = 6
# Sample 9811: Predicted = 1, True = 1
# Sample 9812: Predicted = 0, True = 0
# Sample 9813: Predicted = 9, True = 9
# Sample 9814: Predicted = 3, True = 3
# Sample 9815: Predicted = 3, True = 3
# Sample 9816: Predicted = 4, True = 4
# Sample 9817: Predicted = 4, True = 4
# Sample 9818: Predicted = 0, True = 0
# Sample 9819: Predicted = 6, True = 6
# Sample 9820: Predicted = 2, True = 2
# Sample 9821: Predicted = 5, True = 5
# Sample 9822: Predicted = 4, True = 4
# Sample 9823: Predicted = 2, True = 2
# Sample 9824: Predicted = 3, True = 3
# Sample 9825: Predicted = 4, True = 4
# Sample 9826: Predicted = 6, True = 6
# Sample 9827: Predicted = 0, True = 0
# Sample 9828: Predicted = 0, True = 0
# Sample 9829: Predicted = 2, True = 2
# Sample 9830: Predicted = 0, True = 0
# Sample 9831: Predicted = 1, True = 1
# Sample 9832: Predicted = 4, True = 4
# Sample 9833: Predicted = 5, True = 5
# Sample 9834: Predicted = 6, True = 6
# Sample 9835: Predicted = 9, True = 7
# Sample 9836: Predicted = 8, True = 8
# Sample 9837: Predicted = 9, True = 9
# Sample 9838: Predicted = 0, True = 0
# Sample 9839: Predicted = 1, True = 1
# Sample 9840: Predicted = 2, True = 2
# Sample 9841: Predicted = 3, True = 3
# Sample 9842: Predicted = 7, True = 4
# Sample 9843: Predicted = 5, True = 5
# Sample 9844: Predicted = 6, True = 6
# Sample 9845: Predicted = 7, True = 7
# Sample 9846: Predicted = 8, True = 8
# Sample 9847: Predicted = 0, True = 0
# Sample 9848: Predicted = 1, True = 1
# Sample 9849: Predicted = 2, True = 2
# Sample 9850: Predicted = 3, True = 3
# Sample 9851: Predicted = 4, True = 4
# Sample 9852: Predicted = 5, True = 5
# Sample 9853: Predicted = 6, True = 6
# Sample 9854: Predicted = 7, True = 7
# Sample 9855: Predicted = 8, True = 8
# Sample 9856: Predicted = 9, True = 9
# Sample 9857: Predicted = 8, True = 8
# Sample 9858: Predicted = 7, True = 7
# Sample 9859: Predicted = 1, True = 1
# Sample 9860: Predicted = 3, True = 3
# Sample 9861: Predicted = 7, True = 7
# Sample 9862: Predicted = 5, True = 5
# Sample 9863: Predicted = 2, True = 2
# Sample 9864: Predicted = 8, True = 8
# Sample 9865: Predicted = 0, True = 0
# Sample 9866: Predicted = 7, True = 7
# Sample 9867: Predicted = 5, True = 5
# Sample 9868: Predicted = 9, True = 9
# Sample 9869: Predicted = 9, True = 9
# Sample 9870: Predicted = 0, True = 0
# Sample 9871: Predicted = 9, True = 9
# Sample 9872: Predicted = 1, True = 1
# Sample 9873: Predicted = 1, True = 1
# Sample 9874: Predicted = 5, True = 5
# Sample 9875: Predicted = 8, True = 8
# Sample 9876: Predicted = 8, True = 8
# Sample 9877: Predicted = 6, True = 6
# Sample 9878: Predicted = 3, True = 3
# Sample 9879: Predicted = 2, True = 2
# Sample 9880: Predicted = 1, True = 1
# Sample 9881: Predicted = 8, True = 8
# Sample 9882: Predicted = 3, True = 3
# Sample 9883: Predicted = 2, True = 2
# Sample 9884: Predicted = 6, True = 6
# Sample 9885: Predicted = 5, True = 5
# Sample 9886: Predicted = 6, True = 6
# Sample 9887: Predicted = 9, True = 7
# Sample 9888: Predicted = 4, True = 4
# Sample 9889: Predicted = 1, True = 1
# Sample 9890: Predicted = 0, True = 0
# Sample 9891: Predicted = 5, True = 5
# Sample 9892: Predicted = 3, True = 3
# Sample 9893: Predicted = 1, True = 1
# Sample 9894: Predicted = 9, True = 9
# Sample 9895: Predicted = 2, True = 2
# Sample 9896: Predicted = 1, True = 1
# Sample 9897: Predicted = 9, True = 9
# Sample 9898: Predicted = 6, True = 6
# Sample 9899: Predicted = 0, True = 0
# Sample 9900: Predicted = 4, True = 4
# Sample 9901: Predicted = 6, True = 6
# Sample 9902: Predicted = 1, True = 1
# Sample 9903: Predicted = 7, True = 7
# Sample 9904: Predicted = 3, True = 3
# Sample 9905: Predicted = 8, True = 8
# Sample 9906: Predicted = 7, True = 7
# Sample 9907: Predicted = 2, True = 2
# Sample 9908: Predicted = 9, True = 9
# Sample 9909: Predicted = 6, True = 6
# Sample 9910: Predicted = 5, True = 5
# Sample 9911: Predicted = 8, True = 8
# Sample 9912: Predicted = 3, True = 3
# Sample 9913: Predicted = 5, True = 5
# Sample 9914: Predicted = 7, True = 7
# Sample 9915: Predicted = 1, True = 1
# Sample 9916: Predicted = 6, True = 6
# Sample 9917: Predicted = 1, True = 1
# Sample 9918: Predicted = 0, True = 0
# Sample 9919: Predicted = 9, True = 9
# Sample 9920: Predicted = 6, True = 6
# Sample 9921: Predicted = 2, True = 2
# Sample 9922: Predicted = 5, True = 5
# Sample 9923: Predicted = 4, True = 4
# Sample 9924: Predicted = 2, True = 2
# Sample 9925: Predicted = 3, True = 3
# Sample 9926: Predicted = 4, True = 4
# Sample 9927: Predicted = 4, True = 4
# Sample 9928: Predicted = 6, True = 6
# Sample 9929: Predicted = 0, True = 0
# Sample 9930: Predicted = 0, True = 0
# Sample 9931: Predicted = 2, True = 2
# Sample 9932: Predicted = 0, True = 0
# Sample 9933: Predicted = 1, True = 1
# Sample 9934: Predicted = 2, True = 2
# Sample 9935: Predicted = 3, True = 3
# Sample 9936: Predicted = 9, True = 4
# Sample 9937: Predicted = 3, True = 5
# Sample 9938: Predicted = 6, True = 6
# Sample 9939: Predicted = 7, True = 7
# Sample 9940: Predicted = 8, True = 8
# Sample 9941: Predicted = 9, True = 9
# Sample 9942: Predicted = 0, True = 0
# Sample 9943: Predicted = 1, True = 1
# Sample 9944: Predicted = 2, True = 2
# Sample 9945: Predicted = 3, True = 3
# Sample 9946: Predicted = 4, True = 4
# Sample 9947: Predicted = 5, True = 5
# Sample 9948: Predicted = 6, True = 6
# Sample 9949: Predicted = 7, True = 7
# Sample 9950: Predicted = 8, True = 8
# Sample 9951: Predicted = 9, True = 9
# Sample 9952: Predicted = 0, True = 0
# Sample 9953: Predicted = 1, True = 1
# Sample 9954: Predicted = 2, True = 2
# Sample 9955: Predicted = 8, True = 3
# Sample 9956: Predicted = 4, True = 4
# Sample 9957: Predicted = 5, True = 5
# Sample 9958: Predicted = 6, True = 6
# Sample 9959: Predicted = 7, True = 7
# Sample 9960: Predicted = 8, True = 8
# Sample 9961: Predicted = 9, True = 9
# Sample 9962: Predicted = 8, True = 8
# Sample 9963: Predicted = 6, True = 6
# Sample 9964: Predicted = 5, True = 5
# Sample 9965: Predicted = 0, True = 0
# Sample 9966: Predicted = 6, True = 6
# Sample 9967: Predicted = 8, True = 8
# Sample 9968: Predicted = 9, True = 9
# Sample 9969: Predicted = 4, True = 4
# Sample 9970: Predicted = 1, True = 1
# Sample 9971: Predicted = 9, True = 9
# Sample 9972: Predicted = 3, True = 5
# Sample 9973: Predicted = 8, True = 3
# Sample 9974: Predicted = 0, True = 0
# Sample 9975: Predicted = 4, True = 4
# Sample 9976: Predicted = 8, True = 8
# Sample 9977: Predicted = 9, True = 9
# Sample 9978: Predicted = 1, True = 1
# Sample 9979: Predicted = 4, True = 4
# Sample 9980: Predicted = 0, True = 0
# Sample 9981: Predicted = 5, True = 5
# Sample 9982: Predicted = 3, True = 5
# Sample 9983: Predicted = 2, True = 2
# Sample 9984: Predicted = 1, True = 1
# Sample 9985: Predicted = 5, True = 5
# Sample 9986: Predicted = 4, True = 4
# Sample 9987: Predicted = 0, True = 0
# Sample 9988: Predicted = 7, True = 7
# Sample 9989: Predicted = 6, True = 6
# Sample 9990: Predicted = 0, True = 0
# Sample 9991: Predicted = 1, True = 1
# Sample 9992: Predicted = 7, True = 7
# Sample 9993: Predicted = 0, True = 0
# Sample 9994: Predicted = 6, True = 6
# Sample 9995: Predicted = 8, True = 8
# Sample 9996: Predicted = 9, True = 9
# Sample 9997: Predicted = 5, True = 5
# Sample 9998: Predicted = 1, True = 1
# Sample 9999: Predicted = 7, True = 7
# Sample 10000: Predicted = 9, True = 9
# Sample 10001: Predicted = 8, True = 8
# Sample 10002: Predicted = 6, True = 6
# Sample 10003: Predicted = 0, True = 0
# Sample 10004: Predicted = 8, True = 8
# Sample 10005: Predicted = 1, True = 1
# Sample 10006: Predicted = 7, True = 7
# Sample 10007: Predicted = 7, True = 7
# Sample 10008: Predicted = 1, True = 1
# Sample 10009: Predicted = 3, True = 3
# Sample 10010: Predicted = 2, True = 2
# Sample 10011: Predicted = 3, True = 3
# Sample 10012: Predicted = 1, True = 1
# Sample 10013: Predicted = 4, True = 4
# Sample 10014: Predicted = 2, True = 2
# Sample 10015: Predicted = 5, True = 0
# Sample 10016: Predicted = 0, True = 0
# Sample 10017: Predicted = 7, True = 7
# Sample 10018: Predicted = 8, True = 8
# Sample 10019: Predicted = 4, True = 4
# Sample 10020: Predicted = 6, True = 6
# Sample 10021: Predicted = 4, True = 4
# Sample 10022: Predicted = 9, True = 9
# Sample 10023: Predicted = 9, True = 3
# Sample 10024: Predicted = 8, True = 8
# Sample 10025: Predicted = 4, True = 4
# Sample 10026: Predicted = 7, True = 7
# Sample 10027: Predicted = 2, True = 2
# Sample 10028: Predicted = 5, True = 5
# Sample 10029: Predicted = 6, True = 6
# Sample 10030: Predicted = 3, True = 3
# Sample 10031: Predicted = 6, True = 6
# Sample 10032: Predicted = 9, True = 9
# Sample 10033: Predicted = 6, True = 6
# Sample 10034: Predicted = 3, True = 3
# Sample 10035: Predicted = 2, True = 2
# Sample 10036: Predicted = 2, True = 2
# Sample 10037: Predicted = 4, True = 4
# Sample 10038: Predicted = 6, True = 6
# Sample 10039: Predicted = 9, True = 9
# Sample 10040: Predicted = 0, True = 0
# Sample 10041: Predicted = 2, True = 2
# Sample 10042: Predicted = 5, True = 5
# Sample 10043: Predicted = 5, True = 5
# Sample 10044: Predicted = 1, True = 1
# Sample 10045: Predicted = 9, True = 3
# Sample 10046: Predicted = 8, True = 3
# Sample 10047: Predicted = 9, True = 9
# Sample 10048: Predicted = 7, True = 7
# Sample 10049: Predicted = 8, True = 8
# Sample 10050: Predicted = 7, True = 7
# Sample 10051: Predicted = 2, True = 2
# Sample 10052: Predicted = 2, True = 2
# Sample 10053: Predicted = 5, True = 5
# Sample 10054: Predicted = 7, True = 7
# Sample 10055: Predicted = 9, True = 9
# Sample 10056: Predicted = 8, True = 8
# Sample 10057: Predicted = 2, True = 2
# Sample 10058: Predicted = 1, True = 1
# Sample 10059: Predicted = 9, True = 3
# Sample 10060: Predicted = 1, True = 1
# Sample 10061: Predicted = 3, True = 3
# Sample 10062: Predicted = 0, True = 0
# Sample 10063: Predicted = 1, True = 1
# Sample 10064: Predicted = 2, True = 2
# Sample 10065: Predicted = 3, True = 3
# Sample 10066: Predicted = 4, True = 4
# Sample 10067: Predicted = 5, True = 5
# Sample 10068: Predicted = 6, True = 6
# Sample 10069: Predicted = 7, True = 7
# Sample 10070: Predicted = 8, True = 8
# Sample 10071: Predicted = 9, True = 9
# Sample 10072: Predicted = 0, True = 0
# Sample 10073: Predicted = 1, True = 1
# Sample 10074: Predicted = 2, True = 2
# Sample 10075: Predicted = 3, True = 3
# Sample 10076: Predicted = 4, True = 4
# Sample 10077: Predicted = 5, True = 5
# Sample 10078: Predicted = 6, True = 6
# Sample 10079: Predicted = 7, True = 7
# Sample 10080: Predicted = 8, True = 8
# Sample 10081: Predicted = 9, True = 9
# Sample 10082: Predicted = 0, True = 0
# Sample 10083: Predicted = 1, True = 1
# Sample 10084: Predicted = 2, True = 2
# Sample 10085: Predicted = 3, True = 3
# Sample 10086: Predicted = 4, True = 4
# Sample 10087: Predicted = 5, True = 5
# Sample 10088: Predicted = 6, True = 6
# Sample 10089: Predicted = 7, True = 7
# Sample 10090: Predicted = 8, True = 8
# Sample 10091: Predicted = 9, True = 9
# Sample 10092: Predicted = 1, True = 1
# Sample 10093: Predicted = 2, True = 2
# Sample 10094: Predicted = 6, True = 6
# Sample 10095: Predicted = 5, True = 5
# Sample 10096: Predicted = 3, True = 3
# Sample 10097: Predicted = 0, True = 0
# Sample 10098: Predicted = 7, True = 7
# Sample 10099: Predicted = 0, True = 0
# Sample 10100: Predicted = 4, True = 4
# Sample 10101: Predicted = 1, True = 1
# Sample 10102: Predicted = 4, True = 4
# Sample 10103: Predicted = 3, True = 3
# Sample 10104: Predicted = 6, True = 6
# Sample 10105: Predicted = 7, True = 7
# Sample 10106: Predicted = 2, True = 2
# Sample 10107: Predicted = 3, True = 3
# Sample 10108: Predicted = 1, True = 1
# Sample 10109: Predicted = 2, True = 2
# Sample 10110: Predicted = 1, True = 1
# Sample 10111: Predicted = 2, True = 2
# Sample 10112: Predicted = 9, True = 9
# Sample 10113: Predicted = 6, True = 6
# Sample 10114: Predicted = 0, True = 0
# Sample 10115: Predicted = 1, True = 1
# Sample 10116: Predicted = 3, True = 3
# Sample 10117: Predicted = 0, True = 0
# Sample 10118: Predicted = 2, True = 2
# Sample 10119: Predicted = 7, True = 7
# Sample 10120: Predicted = 5, True = 5
# Sample 10121: Predicted = 7, True = 7
# Sample 10122: Predicted = 6, True = 6
# Sample 10123: Predicted = 2, True = 2
# Sample 10124: Predicted = 9, True = 9
# Sample 10125: Predicted = 1, True = 1
# Sample 10126: Predicted = 9, True = 9
# Sample 10127: Predicted = 0, True = 0
# Sample 10128: Predicted = 6, True = 6
# Sample 10129: Predicted = 0, True = 0
# Sample 10130: Predicted = 6, True = 6
# Sample 10131: Predicted = 0, True = 0
# Sample 10132: Predicted = 2, True = 2
# Sample 10133: Predicted = 0, True = 0
# Sample 10134: Predicted = 6, True = 6
# Sample 10135: Predicted = 1, True = 1
# Sample 10136: Predicted = 5, True = 5
# Sample 10137: Predicted = 8, True = 8
# Sample 10138: Predicted = 4, True = 4
# Sample 10139: Predicted = 3, True = 3
# Sample 10140: Predicted = 0, True = 0
# Sample 10141: Predicted = 1, True = 1
# Sample 10142: Predicted = 5, True = 5
# Sample 10143: Predicted = 4, True = 4
# Sample 10144: Predicted = 4, True = 4
# Sample 10145: Predicted = 8, True = 8
# Sample 10146: Predicted = 5, True = 5
# Sample 10147: Predicted = 7, True = 7
# Sample 10148: Predicted = 5, True = 5
# Sample 10149: Predicted = 7, True = 7
# Sample 10150: Predicted = 8, True = 8
# Sample 10151: Predicted = 3, True = 3
# Sample 10152: Predicted = 4, True = 4
# Sample 10153: Predicted = 8, True = 8
# Sample 10154: Predicted = 8, True = 8
# Sample 10155: Predicted = 5, True = 5
# Sample 10156: Predicted = 2, True = 2
# Sample 10157: Predicted = 9, True = 9
# Sample 10158: Predicted = 7, True = 7
# Sample 10159: Predicted = 1, True = 1
# Sample 10160: Predicted = 3, True = 3
# Sample 10161: Predicted = 8, True = 8
# Sample 10162: Predicted = 1, True = 1
# Sample 10163: Predicted = 0, True = 0
# Sample 10164: Predicted = 7, True = 7
# Sample 10165: Predicted = 5, True = 5
# Sample 10166: Predicted = 3, True = 9
# Sample 10167: Predicted = 6, True = 6
# Sample 10168: Predicted = 9, True = 9
# Sample 10169: Predicted = 4, True = 4
# Sample 10170: Predicted = 7, True = 7
# Sample 10171: Predicted = 7, True = 7
# Sample 10172: Predicted = 9, True = 9
# Sample 10173: Predicted = 9, True = 9
# Sample 10174: Predicted = 3, True = 3
# Sample 10175: Predicted = 4, True = 4
# Sample 10176: Predicted = 4, True = 4
# Sample 10177: Predicted = 3, True = 3
# Sample 10178: Predicted = 8, True = 8
# Sample 10179: Predicted = 6, True = 6
# Sample 10180: Predicted = 2, True = 2
# Sample 10181: Predicted = 0, True = 0
# Sample 10182: Predicted = 1, True = 1
# Sample 10183: Predicted = 2, True = 2
# Sample 10184: Predicted = 3, True = 3
# Sample 10185: Predicted = 4, True = 4
# Sample 10186: Predicted = 5, True = 5
# Sample 10187: Predicted = 6, True = 6
# Sample 10188: Predicted = 7, True = 7
# Sample 10189: Predicted = 8, True = 8
# Sample 10190: Predicted = 9, True = 9
# Sample 10191: Predicted = 0, True = 0
# Sample 10192: Predicted = 1, True = 1
# Sample 10193: Predicted = 2, True = 2
# Sample 10194: Predicted = 3, True = 3
# Sample 10195: Predicted = 4, True = 4
# Sample 10196: Predicted = 5, True = 5
# Sample 10197: Predicted = 6, True = 6
# Sample 10198: Predicted = 7, True = 7
# Sample 10199: Predicted = 8, True = 8
# Sample 10200: Predicted = 9, True = 9
# Sample 10201: Predicted = 0, True = 0
# Sample 10202: Predicted = 1, True = 1
# Sample 10203: Predicted = 2, True = 2
# Sample 10204: Predicted = 3, True = 3
# Sample 10205: Predicted = 4, True = 4
# Sample 10206: Predicted = 5, True = 5
# Sample 10207: Predicted = 6, True = 6
# Sample 10208: Predicted = 7, True = 7
# Sample 10209: Predicted = 8, True = 8
# Sample 10210: Predicted = 9, True = 9
# Sample 10211: Predicted = 0, True = 0
# Sample 10212: Predicted = 8, True = 8
# Sample 10213: Predicted = 3, True = 3
# Sample 10214: Predicted = 9, True = 9
# Sample 10215: Predicted = 5, True = 5
# Sample 10216: Predicted = 5, True = 5
# Sample 10217: Predicted = 2, True = 2
# Sample 10218: Predicted = 6, True = 6
# Sample 10219: Predicted = 8, True = 8
# Sample 10220: Predicted = 4, True = 4
# Sample 10221: Predicted = 9, True = 9
# Sample 10222: Predicted = 1, True = 1
# Sample 10223: Predicted = 7, True = 7
# Sample 10224: Predicted = 1, True = 1
# Sample 10225: Predicted = 2, True = 2
# Sample 10226: Predicted = 3, True = 3
# Sample 10227: Predicted = 5, True = 5
# Sample 10228: Predicted = 9, True = 9
# Sample 10229: Predicted = 6, True = 6
# Sample 10230: Predicted = 9, True = 9
# Sample 10231: Predicted = 1, True = 1
# Sample 10232: Predicted = 1, True = 1
# Sample 10233: Predicted = 1, True = 1
# Sample 10234: Predicted = 2, True = 2
# Sample 10235: Predicted = 9, True = 9
# Sample 10236: Predicted = 5, True = 5
# Sample 10237: Predicted = 6, True = 6
# Sample 10238: Predicted = 8, True = 8
# Sample 10239: Predicted = 1, True = 1
# Sample 10240: Predicted = 2, True = 2
# Sample 10241: Predicted = 0, True = 0
# Sample 10242: Predicted = 7, True = 7
# Sample 10243: Predicted = 7, True = 7
# Sample 10244: Predicted = 5, True = 5
# Sample 10245: Predicted = 8, True = 8
# Sample 10246: Predicted = 2, True = 2
# Sample 10247: Predicted = 9, True = 9
# Sample 10248: Predicted = 8, True = 8
# Sample 10249: Predicted = 9, True = 9
# Sample 10250: Predicted = 0, True = 0
# Sample 10251: Predicted = 4, True = 4
# Sample 10252: Predicted = 6, True = 6
# Sample 10253: Predicted = 7, True = 7
# Sample 10254: Predicted = 1, True = 1
# Sample 10255: Predicted = 3, True = 3
# Sample 10256: Predicted = 4, True = 4
# Sample 10257: Predicted = 5, True = 5
# Sample 10258: Predicted = 6, True = 6
# Sample 10259: Predicted = 0, True = 0
# Sample 10260: Predicted = 3, True = 3
# Sample 10261: Predicted = 6, True = 6
# Sample 10262: Predicted = 8, True = 8
# Sample 10263: Predicted = 7, True = 7
# Sample 10264: Predicted = 0, True = 0
# Sample 10265: Predicted = 4, True = 4
# Sample 10266: Predicted = 2, True = 2
# Sample 10267: Predicted = 7, True = 7
# Sample 10268: Predicted = 4, True = 4
# Sample 10269: Predicted = 7, True = 7
# Sample 10270: Predicted = 5, True = 5
# Sample 10271: Predicted = 4, True = 4
# Sample 10272: Predicted = 3, True = 3
# Sample 10273: Predicted = 4, True = 4
# Sample 10274: Predicted = 2, True = 2
# Sample 10275: Predicted = 8, True = 8
# Sample 10276: Predicted = 1, True = 1
# Sample 10277: Predicted = 5, True = 5
# Sample 10278: Predicted = 1, True = 1
# Sample 10279: Predicted = 2, True = 2
# Sample 10280: Predicted = 0, True = 0
# Sample 10281: Predicted = 2, True = 2
# Sample 10282: Predicted = 5, True = 5
# Sample 10283: Predicted = 6, True = 6
# Sample 10284: Predicted = 4, True = 4
# Sample 10285: Predicted = 3, True = 3
# Sample 10286: Predicted = 0, True = 0
# Sample 10287: Predicted = 0, True = 0
# Sample 10288: Predicted = 0, True = 0
# Sample 10289: Predicted = 3, True = 3
# ...
# Sample 13582: Predicted = 3, True = 3
# Sample 13583: Predicted = 5, True = 5
# Sample 13584: Predicted = 5, True = 5
# Sample 13585: Predicted = 0, True = 0
# Sample 13586: Predicted = 7, True = 7
# Sample 13587: Predicted = 4, True = 9
# Sample 13588: Predicted = 5, True = 5
# Sample 13589: Predicted = 6, True = 6
# Sample 13590: Predicted = 5, True = 5
# Sample 13591: Predicted = 1, True = 1
# Sample 13592: Predicted = 4, True = 4
# Sample 13593: Predicted = 1, True = 1
# Sample 13594: Predicted = 1, True = 1
# Sample 13595: Predicted = 2, True = 2
# Sample 13596: Predicted = 8, True = 8
# Sample 13597: Predicted = 2, True = 2
# Sample 13598: Predicted = 6, True = 6
# Sample 13599: Predicted = 1, True = 1
# Sample 13600: Predicted = 5, True = 5
# Sample 13601: Predicted = 0, True = 0
# Sample 13602: Predicted = 1, True = 1
# Sample 13603: Predicted = 2, True = 2
# Sample 13604: Predicted = 3, True = 3
# Sample 13605: Predicted = 4, True = 4
# Sample 13606: Predicted = 5, True = 5
# Sample 13607: Predicted = 5, True = 6
# Sample 13608: Predicted = 7, True = 7
# Sample 13609: Predicted = 8, True = 8
# Sample 13610: Predicted = 9, True = 9
# Sample 13611: Predicted = 0, True = 0
# Sample 13612: Predicted = 1, True = 1
# Sample 13613: Predicted = 2, True = 2
# Sample 13614: Predicted = 3, True = 3
# Sample 13615: Predicted = 4, True = 4
# Sample 13616: Predicted = 5, True = 5
# Sample 13617: Predicted = 6, True = 6
# Sample 13618: Predicted = 7, True = 7
# Sample 13619: Predicted = 8, True = 8
# Sample 13620: Predicted = 9, True = 9
# Sample 13621: Predicted = 0, True = 0
# Sample 13622: Predicted = 1, True = 1
# Sample 13623: Predicted = 2, True = 2
# Sample 13624: Predicted = 3, True = 3
# Sample 13625: Predicted = 4, True = 4
# Sample 13626: Predicted = 5, True = 5
# Sample 13627: Predicted = 6, True = 6
# Sample 13628: Predicted = 7, True = 7
# Sample 13629: Predicted = 8, True = 8
# Sample 13630: Predicted = 8, True = 8
# Sample 13631: Predicted = 0, True = 0
# Sample 13632: Predicted = 6, True = 6
# Sample 13633: Predicted = 0, True = 0
# Sample 13634: Predicted = 3, True = 0
# Sample 13635: Predicted = 2, True = 2
# Sample 13636: Predicted = 3, True = 3
# Sample 13637: Predicted = 7, True = 7
# Sample 13638: Predicted = 9, True = 9
# Sample 13639: Predicted = 4, True = 4
# Sample 13640: Predicted = 7, True = 7
# Sample 13641: Predicted = 1, True = 1
# Sample 13642: Predicted = 7, True = 9
# Sample 13643: Predicted = 7, True = 1
# Sample 13644: Predicted = 7, True = 7
# Sample 13645: Predicted = 1, True = 1
# Sample 13646: Predicted = 4, True = 4
# Sample 13647: Predicted = 0, True = 0
# Sample 13648: Predicted = 0, True = 0
# Sample 13649: Predicted = 1, True = 1
# Sample 13650: Predicted = 7, True = 7
# Sample 13651: Predicted = 5, True = 5
# Sample 13652: Predicted = 7, True = 7
# Sample 13653: Predicted = 1, True = 1
# Sample 13654: Predicted = 3, True = 3
# Sample 13655: Predicted = 3, True = 3
# Sample 13656: Predicted = 3, True = 3
# Sample 13657: Predicted = 1, True = 1
# Sample 13658: Predicted = 6, True = 6
# Sample 13659: Predicted = 9, True = 9
# Sample 13660: Predicted = 7, True = 7
# Sample 13661: Predicted = 1, True = 1
# Sample 13662: Predicted = 3, True = 3
# Sample 13663: Predicted = 0, True = 0
# Sample 13664: Predicted = 7, True = 2
# Sample 13665: Predicted = 6, True = 6
# Sample 13666: Predicted = 0, True = 0
# Sample 13667: Predicted = 8, True = 8
# Sample 13668: Predicted = 9, True = 9
# Sample 13669: Predicted = 5, True = 4
# Sample 13670: Predicted = 3, True = 3
# Sample 13671: Predicted = 5, True = 5
# Sample 13672: Predicted = 4, True = 4
# Sample 13673: Predicted = 8, True = 8
# Sample 13674: Predicted = 1, True = 1
# Sample 13675: Predicted = 5, True = 5
# Sample 13676: Predicted = 9, True = 9
# Sample 13677: Predicted = 0, True = 0
# Sample 13678: Predicted = 6, True = 6
# Sample 13679: Predicted = 5, True = 6
# Sample 13680: Predicted = 3, True = 3
# Sample 13681: Predicted = 8, True = 8
# Sample 13682: Predicted = 1, True = 1
# Sample 13683: Predicted = 4, True = 4
# Sample 13684: Predicted = 7, True = 7
# Sample 13685: Predicted = 5, True = 5
# Sample 13686: Predicted = 2, True = 2
# Sample 13687: Predicted = 0, True = 0
# Sample 13688: Predicted = 0, True = 0
# Sample 13689: Predicted = 1, True = 1
# Sample 13690: Predicted = 7, True = 7
# Sample 13691: Predicted = 8, True = 8
# Sample 13692: Predicted = 7, True = 9
# Sample 13693: Predicted = 6, True = 6
# Sample 13694: Predicted = 8, True = 8
# Sample 13695: Predicted = 8, True = 8
# Sample 13696: Predicted = 2, True = 2
# Sample 13697: Predicted = 3, True = 3
# Sample 13698: Predicted = 5, True = 6
# Sample 13699: Predicted = 1, True = 1
# Sample 13700: Predicted = 2, True = 2
# Sample 13701: Predicted = 9, True = 9
# Sample 13702: Predicted = 5, True = 5
# Sample 13703: Predicted = 2, True = 2
# Sample 13704: Predicted = 0, True = 0
# Sample 13705: Predicted = 1, True = 1
# Sample 13706: Predicted = 2, True = 2
# Sample 13707: Predicted = 3, True = 3
# Sample 13708: Predicted = 4, True = 4
# Sample 13709: Predicted = 5, True = 5
# Sample 13710: Predicted = 6, True = 6
# Sample 13711: Predicted = 7, True = 7
# Sample 13712: Predicted = 8, True = 8
# Sample 13713: Predicted = 9, True = 9
# Sample 13714: Predicted = 0, True = 0
# Sample 13715: Predicted = 1, True = 1
# Sample 13716: Predicted = 2, True = 2
# Sample 13717: Predicted = 3, True = 3
# Sample 13718: Predicted = 4, True = 4
# Sample 13719: Predicted = 5, True = 5
# Sample 13720: Predicted = 6, True = 6
# Sample 13721: Predicted = 7, True = 7
# Sample 13722: Predicted = 8, True = 8
# Sample 13723: Predicted = 9, True = 9
# Sample 13724: Predicted = 0, True = 0
# Sample 13725: Predicted = 1, True = 1
# Sample 13726: Predicted = 2, True = 2
# Sample 13727: Predicted = 3, True = 3
# Sample 13728: Predicted = 4, True = 4
# Sample 13729: Predicted = 6, True = 5
# Sample 13730: Predicted = 6, True = 6
# Sample 13731: Predicted = 7, True = 7
# Sample 13732: Predicted = 8, True = 8
# Sample 13733: Predicted = 9, True = 9
# Sample 13734: Predicted = 7, True = 7
# Sample 13735: Predicted = 4, True = 4
# Sample 13736: Predicted = 6, True = 6
# Sample 13737: Predicted = 1, True = 1
# Sample 13738: Predicted = 4, True = 4
# Sample 13739: Predicted = 0, True = 0
# Sample 13740: Predicted = 9, True = 9
# Sample 13741: Predicted = 9, True = 9
# Sample 13742: Predicted = 3, True = 3
# Sample 13743: Predicted = 7, True = 7
# Sample 13744: Predicted = 1, True = 8
# Sample 13745: Predicted = 0, True = 4
# Sample 13746: Predicted = 7, True = 7
# Sample 13747: Predicted = 5, True = 5
# Sample 13748: Predicted = 8, True = 8
# Sample 13749: Predicted = 6, True = 5
# Sample 13750: Predicted = 3, True = 3
# Sample 13751: Predicted = 2, True = 2
# Sample 13752: Predicted = 2, True = 2
# Sample 13753: Predicted = 0, True = 0
# Sample 13754: Predicted = 5, True = 5
# Sample 13755: Predicted = 8, True = 8
# Sample 13756: Predicted = 6, True = 6
# Sample 13757: Predicted = 0, True = 0
# Sample 13758: Predicted = 3, True = 3
# Sample 13759: Predicted = 8, True = 8
# Sample 13760: Predicted = 1, True = 1
# Sample 13761: Predicted = 0, True = 0
# Sample 13762: Predicted = 3, True = 3
# Sample 13763: Predicted = 0, True = 0
# Sample 13764: Predicted = 4, True = 4
# Sample 13765: Predicted = 7, True = 7
# Sample 13766: Predicted = 4, True = 4
# Sample 13767: Predicted = 9, True = 9
# Sample 13768: Predicted = 0, True = 2
# Sample 13769: Predicted = 9, True = 9
# Sample 13770: Predicted = 0, True = 5
# Sample 13771: Predicted = 7, True = 7
# Sample 13772: Predicted = 1, True = 1
# Sample 13773: Predicted = 7, True = 7
# Sample 13774: Predicted = 1, True = 1
# Sample 13775: Predicted = 6, True = 6
# Sample 13776: Predicted = 6, True = 6
# Sample 13777: Predicted = 5, True = 5
# Sample 13778: Predicted = 6, True = 6
# Sample 13779: Predicted = 0, True = 2
# Sample 13780: Predicted = 8, True = 8
# Sample 13781: Predicted = 7, True = 7
# Sample 13782: Predicted = 6, True = 6
# Sample 13783: Predicted = 4, True = 4
# Sample 13784: Predicted = 9, True = 9
# Sample 13785: Predicted = 9, True = 9
# Sample 13786: Predicted = 5, True = 5
# Sample 13787: Predicted = 3, True = 3
# Sample 13788: Predicted = 7, True = 7
# Sample 13789: Predicted = 4, True = 4
# Sample 13790: Predicted = 3, True = 3
# Sample 13791: Predicted = 0, True = 0
# Sample 13792: Predicted = 9, True = 4
# Sample 13793: Predicted = 6, True = 6
# Sample 13794: Predicted = 6, True = 6
# Sample 13795: Predicted = 1, True = 1
# Sample 13796: Predicted = 1, True = 1
# Sample 13797: Predicted = 3, True = 3
# Sample 13798: Predicted = 2, True = 2
# Sample 13799: Predicted = 1, True = 1
# Sample 13800: Predicted = 0, True = 0
# Sample 13801: Predicted = 0, True = 0
# Sample 13802: Predicted = 1, True = 1
# Sample 13803: Predicted = 2, True = 2
# Sample 13804: Predicted = 3, True = 3
# Sample 13805: Predicted = 4, True = 4
# Sample 13806: Predicted = 7, True = 7
# Sample 13807: Predicted = 8, True = 8
# Sample 13808: Predicted = 4, True = 9
# Sample 13809: Predicted = 0, True = 0
# Sample 13810: Predicted = 1, True = 1
# Sample 13811: Predicted = 8, True = 2
# Sample 13812: Predicted = 3, True = 3
# Sample 13813: Predicted = 4, True = 4
# Sample 13814: Predicted = 5, True = 5
# Sample 13815: Predicted = 6, True = 6
# Sample 13816: Predicted = 7, True = 7
# Sample 13817: Predicted = 8, True = 8
# Sample 13818: Predicted = 0, True = 0
# Sample 13819: Predicted = 1, True = 1
# Sample 13820: Predicted = 2, True = 2
# Sample 13821: Predicted = 3, True = 3
# Sample 13822: Predicted = 4, True = 4
# Sample 13823: Predicted = 7, True = 7
# Sample 13824: Predicted = 8, True = 8
# Sample 13825: Predicted = 9, True = 9
# Sample 13826: Predicted = 0, True = 0
# Sample 13827: Predicted = 8, True = 8
# Sample 13828: Predicted = 3, True = 3
# Sample 13829: Predicted = 9, True = 9
# Sample 13830: Predicted = 5, True = 5
# Sample 13831: Predicted = 5, True = 5
# Sample 13832: Predicted = 2, True = 2
# Sample 13833: Predicted = 6, True = 6
# Sample 13834: Predicted = 8, True = 8
# Sample 13835: Predicted = 4, True = 4
# Sample 13836: Predicted = 1, True = 1
# Sample 13837: Predicted = 7, True = 7
# Sample 13838: Predicted = 1, True = 1
# Sample 13839: Predicted = 7, True = 2
# Sample 13840: Predicted = 3, True = 3
# Sample 13841: Predicted = 5, True = 5
# Sample 13842: Predicted = 6, True = 6
# Sample 13843: Predicted = 9, True = 9
# Sample 13844: Predicted = 1, True = 1
# Sample 13845: Predicted = 1, True = 1
# Sample 13846: Predicted = 1, True = 1
# Sample 13847: Predicted = 2, True = 2
# Sample 13848: Predicted = 1, True = 1
# Sample 13849: Predicted = 2, True = 2
# Sample 13850: Predicted = 0, True = 0
# Sample 13851: Predicted = 7, True = 7
# Sample 13852: Predicted = 7, True = 7
# Sample 13853: Predicted = 5, True = 5
# Sample 13854: Predicted = 8, True = 8
# Sample 13855: Predicted = 2, True = 2
# Sample 13856: Predicted = 9, True = 9
# Sample 13857: Predicted = 8, True = 8
# Sample 13858: Predicted = 6, True = 6
# Sample 13859: Predicted = 7, True = 7
# Sample 13860: Predicted = 3, True = 3
# Sample 13861: Predicted = 4, True = 4
# Sample 13862: Predicted = 6, True = 6
# Sample 13863: Predicted = 8, True = 8
# Sample 13864: Predicted = 7, True = 7
# Sample 13865: Predicted = 0, True = 0
# Sample 13866: Predicted = 4, True = 4
# Sample 13867: Predicted = 2, True = 2
# Sample 13868: Predicted = 7, True = 7
# Sample 13869: Predicted = 7, True = 7
# Sample 13870: Predicted = 5, True = 5
# Sample 13871: Predicted = 4, True = 4
# Sample 13872: Predicted = 3, True = 3
# Sample 13873: Predicted = 4, True = 4
# Sample 13874: Predicted = 2, True = 2
# Sample 13875: Predicted = 8, True = 8
# Sample 13876: Predicted = 1, True = 1
# Sample 13877: Predicted = 5, True = 5
# Sample 13878: Predicted = 1, True = 1
# Sample 13879: Predicted = 0, True = 0
# Sample 13880: Predicted = 2, True = 2
# Sample 13881: Predicted = 3, True = 3
# Sample 13882: Predicted = 3, True = 3
# Sample 13883: Predicted = 5, True = 5
# Sample 13884: Predicted = 7, True = 7
# Sample 13885: Predicted = 0, True = 0
# Sample 13886: Predicted = 6, True = 6
# Sample 13887: Predicted = 8, True = 8
# Sample 13888: Predicted = 6, True = 6
# Sample 13889: Predicted = 3, True = 3
# Sample 13890: Predicted = 9, True = 9
# Sample 13891: Predicted = 9, True = 9
# Sample 13892: Predicted = 8, True = 8
# Sample 13893: Predicted = 2, True = 2
# Sample 13894: Predicted = 7, True = 7
# Sample 13895: Predicted = 7, True = 7
# Sample 13896: Predicted = 1, True = 1
# Sample 13897: Predicted = 0, True = 0
# Sample 13898: Predicted = 1, True = 1
# Sample 13899: Predicted = 7, True = 7
# Sample 13900: Predicted = 8, True = 8
# Sample 13901: Predicted = 9, True = 9
# Sample 13902: Predicted = 0, True = 0
# Sample 13903: Predicted = 1, True = 1
# Sample 13904: Predicted = 2, True = 2
# Sample 13905: Predicted = 7, True = 3
# Sample 13906: Predicted = 4, True = 4
# Sample 13907: Predicted = 5, True = 5
# Sample 13908: Predicted = 6, True = 6
# Sample 13909: Predicted = 7, True = 7
# Sample 13910: Predicted = 8, True = 8
# Sample 13911: Predicted = 0, True = 0
# Sample 13912: Predicted = 1, True = 1
# Sample 13913: Predicted = 2, True = 2
# Sample 13914: Predicted = 3, True = 3
# Sample 13915: Predicted = 4, True = 4
# Sample 13916: Predicted = 7, True = 7
# Sample 13917: Predicted = 8, True = 8
# Sample 13918: Predicted = 9, True = 9
# Sample 13919: Predicted = 7, True = 7
# Sample 13920: Predicted = 8, True = 8
# Sample 13921: Predicted = 6, True = 6
# Sample 13922: Predicted = 4, True = 4
# Sample 13923: Predicted = 1, True = 1
# Sample 13924: Predicted = 9, True = 9
# Sample 13925: Predicted = 3, True = 3
# Sample 13926: Predicted = 8, True = 8
# Sample 13927: Predicted = 4, True = 4
# Sample 13928: Predicted = 4, True = 4
# Sample 13929: Predicted = 7, True = 7
# Sample 13930: Predicted = 0, True = 0
# Sample 13931: Predicted = 1, True = 1
# Sample 13932: Predicted = 9, True = 9
# Sample 13933: Predicted = 2, True = 2
# Sample 13934: Predicted = 8, True = 8
# Sample 13935: Predicted = 7, True = 7
# Sample 13936: Predicted = 8, True = 8
# Sample 13937: Predicted = 2, True = 2
# Sample 13938: Predicted = 6, True = 6
# Sample 13939: Predicted = 0, True = 0
# Sample 13940: Predicted = 6, True = 6
# Sample 13941: Predicted = 5, True = 5
# Sample 13942: Predicted = 3, True = 3
# Sample 13943: Predicted = 3, True = 3
# Sample 13944: Predicted = 5, True = 3
# Sample 13945: Predicted = 9, True = 9
# Sample 13946: Predicted = 1, True = 1
# Sample 13947: Predicted = 4, True = 4
# Sample 13948: Predicted = 0, True = 0
# Sample 13949: Predicted = 6, True = 6
# Sample 13950: Predicted = 1, True = 1
# Sample 13951: Predicted = 0, True = 0
# Sample 13952: Predicted = 0, True = 0
# Sample 13953: Predicted = 6, True = 6
# Sample 13954: Predicted = 2, True = 2
# Sample 13955: Predicted = 1, True = 1
# Sample 13956: Predicted = 1, True = 1
# Sample 13957: Predicted = 7, True = 7
# Sample 13958: Predicted = 7, True = 7
# Sample 13959: Predicted = 8, True = 8
# Sample 13960: Predicted = 4, True = 4
# Sample 13961: Predicted = 6, True = 6
# Sample 13962: Predicted = 0, True = 0
# Sample 13963: Predicted = 7, True = 7
# Sample 13964: Predicted = 0, True = 0
# Sample 13965: Predicted = 3, True = 3
# Sample 13966: Predicted = 6, True = 6
# Sample 13967: Predicted = 8, True = 8
# Sample 13968: Predicted = 7, True = 7
# Sample 13969: Predicted = 1, True = 1
# Sample 13970: Predicted = 5, True = 5
# Sample 13971: Predicted = 2, True = 2
# Sample 13972: Predicted = 4, True = 4
# Sample 13973: Predicted = 9, True = 9
# Sample 13974: Predicted = 4, True = 4
# Sample 13975: Predicted = 3, True = 3
# Sample 13976: Predicted = 6, True = 6
# Sample 13977: Predicted = 4, True = 4
# Sample 13978: Predicted = 1, True = 1
# Sample 13979: Predicted = 7, True = 7
# Sample 13980: Predicted = 2, True = 2
# Sample 13981: Predicted = 6, True = 6
# Sample 13982: Predicted = 5, True = 5
# Sample 13983: Predicted = 0, True = 0
# Sample 13984: Predicted = 1, True = 1
# Sample 13985: Predicted = 2, True = 2
# Sample 13986: Predicted = 3, True = 3
# Sample 13987: Predicted = 4, True = 4
# Sample 13988: Predicted = 5, True = 5
# Sample 13989: Predicted = 6, True = 6
# Sample 13990: Predicted = 7, True = 7
# Sample 13991: Predicted = 8, True = 8
# Sample 13992: Predicted = 9, True = 9
# Sample 13993: Predicted = 0, True = 0
# Sample 13994: Predicted = 1, True = 1
# Sample 13995: Predicted = 2, True = 2
# Sample 13996: Predicted = 3, True = 3
# Sample 13997: Predicted = 4, True = 4
# Sample 13998: Predicted = 5, True = 5
# Sample 13999: Predicted = 6, True = 6
# Correct Predictions: 13662, Total Test Samples: 14000
# Test Accuracy: 0.9758571428571429

# %% [markdown]
# ## Part 2 - Neural Network in PyTorch

# %% [markdown]
# ____________

# %% [markdown]
# In this part we learn to:
# 1. Load and preprocess datasets using pytorch.
# 2. Implement and train a neural network (MLP) on the MNIST dataset, using Pytorch.
# 3. Implement and train a convolutional neural network (CNN) on MNIST dataset using Pytorch.

# %% [markdown]
# ### **1. Setup**
# Before running code on Colab:
# - Go to "Runtime" -> "Change runtime type", and make sure to choose "GPU" for Hardware accelerator.
# - Check your Python version at the command line by running "!python --version". It should be Python 3.10 by default.
# - Upload all files of this assignment (code and datasets) to your Drive (e.g "machine_learning_intro/assignments/assignment3") and mount that data to the machine. See the next cell below. In principle, it is also possible to upload files to the local disk of the colab machines. However, such files will be deleted when the machine is restarted.

# %%
# check python version
# !python --version
# Out:
# Python 3.10.12

# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

# Enter the foldername in your Drive where you have saved the code and datasets.
# Recommended path: 'machine_learning_intro/assignments/assignment5/'
FOLDERNAME = 'Machine_learning_Intro_Assignment/'
ASSIGNMENTNAME = 'Assignment5'

# %cd drive/My\ Drive
# %cp -r $FOLDERNAME/$ASSIGNMENTNAME ../../
# %cd ../../
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content

# %% [markdown]
# ### **2. Dataset**

# %% [markdown]
# In this exercise, we are going to build a neural network that identify handwritten digits. We will use the MNIST dataset which consists of greyscale handwritten digits. Each image is 28x28 pixels and there are 10 different digits. The network will take these images and predict the digit in them.

# %% [markdown]
# Let's visualize the data before working with it.
# 1. We can use the "torchvision" package to download the trainset. Set ```transform``` as to be the transform function below (It normalizes each image) and ```train=True```.
# 2. We use torch.utils.data.DataLoader to load the data. Set ```batch_size=64```.

# %%
# load packages
import torch
import numpy as np
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# %%
data_path = "./MNIST_data"

# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])

# Download and load the data
mnist_data = datasets.MNIST(data_path, download=True, train=True, transform=transform)
mnist_dataloader = torch.utils.data.DataLoader(mnist_data, batch_size=64, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./MNIST_data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.4MB/s]
# Extracting ./MNIST_data/MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./MNIST_data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 484kB/s]
# Extracting ./MNIST_data/MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./MNIST_data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.46MB/s]
# Extracting ./MNIST_data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 3.19MB/s]
# Extracting ./MNIST_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST_data/MNIST/raw

# %% [markdown]
# Using the ```mnist_data``` (dataset) and ```mnist dataloader``` (batch dataloader):
# 1. Print the number of samples in the whole dataset.
# 2. Print the number of samples in a single batch.
# 3. Print the shape of images in the data.
# 4. Print the number of labels in the dataset (targets).
# 5. Plot 3 random images using matplotlib (```plt.imshow```) and print their labels.

# %%
# get single batch
dataiter = iter(mnist_dataloader)
batch_images, batch_labels = next(dataiter)

# 1. Print the number of samples in the whole dataset.
num_samples = len(mnist_data)
print("The number of samples in the whole dataset is:", num_samples)

# 2. Print the number of samples in a single batch.

print("The number of samples in a single batch:", batch_images.shape[0])

# 3. Print the shape of images in the data (image dimensions).
image_shape = batch_images.shape[1:]
print("The shape of images in the data is:", image_shape)

# 4. Print the number of labels in the whole dataset (using the targets in the dataloader).
num_labels = np.unique([label for _, label in mnist_data])
print("The number of labels in the whole dataset is:", len(num_labels))
# Out:
# The number of samples in the whole dataset is: 60000
# The number of samples in a single batch: 64
# The shape of images in the data is: torch.Size([1, 28, 28])
# The number of labels in the whole dataset is: 10

# %%
# 5. plot three images and print their labels
idx = np.random.choice(range(64),3) # three rundom indices
plt.subplot(1,3,1)
plt.imshow(batch_images[idx[0]].numpy().squeeze(), cmap='Greys_r')
plt.subplot(1,3,2)
plt.imshow(batch_images[idx[1]].numpy().squeeze(), cmap='Greys_r')
plt.subplot(1,3,3)
plt.imshow(batch_images[idx[2]].numpy().squeeze(), cmap='Greys_r')
print("Labels:",batch_labels[idx])
# Out:
# Labels: tensor([6, 1, 9])

# %% [markdown]
# ### **3. Neural Network - Architecture**

# %% [markdown]
# In the next section, we are going to implement a neural network with pytorch that gets mnist images and recognize the digit in them.
#
# Network Architecture (see image below): **784 input units**, a hidden layer with **128 units** and a **ReLU activation**, then a hidden layer with **64 units** and a **ReLU activation**, and finally an **output layer** with a **log-softmax activation**.
#
# Note: Since simple neural networks get vectors as inputs, and not images (unlike CNNs), we should flatten the data. Each sample with shape (28,28) becomes (784,). That is why the input layer has 784 units.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Complete the code below: The constructor (```__init___```) should contain defenitions of layers like ```Linear``` or ```Relu```. The ```forward``` function should contain the logic between the layers declared in the constructor.

# %% [markdown]
# For this section, as well as the next section, you can follow online tutorials (like **[this tutorial](https://pytorch.org/tutorials/beginner/basics/quickstart_tutorial.html)** or **[this one](https://www.marktechpost.com/2019/11/09/create-a-neural-network-with-pytorch/)**) to understand how to implement neural networks with pytorch.

# %%
from torch import nn, optim
import torch.nn.functional as F

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        '''
        Declare layers for the model
        '''
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512), #input is 784, output is 512
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 10),  # Input: 256, Output: 10
            nn.ReLU()
        )

    def forward(self, x):
        ''' Forward pass through the network, returns log_softmax values '''
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return F.log_softmax(logits, dim=1)


model = NeuralNetwork()
model
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=256, out_features=10, bias=True)
#     (7): ReLU()
#   )
# )

# %% [markdown]
# Now that we have a network, let's see what happens when we pass in an image.
# Let's choose a random image and pass it through the network. It should return a prediction - confidences for each class. The class with the highest confidence is the prediction of the model for that image.
# We visualize the results using ```view_classify``` function below.

# %%
def view_classify(img, ps, version="MNIST"):
    ''' Function for viewing an image and it's predicted classes.
    image - the input image to the network
    ps - the class confidences (network output)
    '''
    ps = ps.data.numpy().squeeze()
    fig, (ax1, ax2) = plt.subplots(figsize=(6,9), ncols=2)
    ax1.imshow(img.resize_(1, 28, 28).numpy().squeeze())
    ax1.axis('off')
    ax2.barh(np.arange(10), ps)
    ax2.set_aspect(0.1)
    ax2.set_yticks(np.arange(10))
    if version == "MNIST":
        ax2.set_yticklabels(np.arange(10))
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)

    plt.tight_layout()

# %%
def random_prediction_example(data_loader, model):
  '''
  The function sample an image from the data, pass it through the model (inference)
  and show the prediction visually. It returns the predictions confidences.
  '''
  # take a batch and randomly pick an image
  dataiter = iter(data_loader)
  images, labels = next(dataiter)
  images.resize_(64, 1, 784)
  img = images[0] #select the first image
  label = labels[0] #true label for reference

# Forward pass through the network
  # we use torch.no_grad() for faster inference and to avoid gradients from
  # moving through the network.
  with torch.no_grad():
    ps = model(img.view(-1, 784))  # Forward pass
    ps = torch.exp(ps)  # Convert log-probabilities to probabilities
    predicted_class = torch.argmax(ps).item()

  # visualize image and prediction
  view_classify(img.view(1, 28, 28), ps)
  return ps, predicted_class, label

# %%
# you can run this cell multiple times for different images
preds_conf, predicted_class, true_label = random_prediction_example(mnist_dataloader, model)

# %% [markdown]
# Print the prediction of the network for that sample:

# %%
# Print the prediction

print(f"True Label: {true_label.item()}, Predicted Class: {predicted_class}")
# Out:
# True Label: 9, Predicted Class: 5

# %% [markdown]
# ### **4. Neural Network - Training**

# %% [markdown]
# We can now train and evaluate our network.
# 1. Split the dataset into a training set and a validation set. Train-set size: 80% of the total data. Val-set size: the rest (20%).
# 2. Create a dataloader for each set (```train_loader``` and ```val_loader```, see Section 2 for examples).
# 3. Choose hyperparameters (for now we choose ```learning_rate=0.003``` and ```num_epochs=5```).
# 4. Use SGD (Stochastic Gradient Descent) as the optimizer.
# 5. Since it is a multi-class classification task, use "negative log-likelihood loss" as the loss criterion.
# 6. Train your model on the train-set and evaluate it on the validation-set.
# 7. During training, for each epoch, track the training loss and validation loss.

# %%
from torch.utils import data

# %%
torch.manual_seed(42)  # Set a random seed for reproducibility
# 1. split trainset into train and validation (use torch.utils.data.random_split())
train_data, val_data = data.random_split(mnist_data, [int(0.8*len(mnist_data)), len(mnist_data) - int(0.8*len(mnist_data))])

# 2.1. create data loader for the trainset (batch_size=64, shuffle=True)

train_loader = data.DataLoader(train_data, batch_size=64, shuffle=True)

# 2.2. create data loader for the valset (batch_size=64, shuffle=False)

val_loader = data.DataLoader(val_data, batch_size = 64, shuffle = False)

# %%
# 3. set hyper parameters
learning_rate = 0.003
nepochs = 5
momentum = 0.9

# %%
model = NeuralNetwork()

# 4. create sgd optimizer. It should optimize our model parameters with
#    learning_rate defined above

optimizer = optim.SGD(model.parameters(), learning_rate, momentum )

# 5. create a criterion object. It should be negative log-likelihood loss since the task
#    is a multi-task classification (digits classification)

criterion = nn.NLLLoss()

# %%
def train_model(model, optimizer, criterion,
                nepochs, train_loader, val_loader, is_image_input=False):
    '''
    Train a pytorch model and evaluate it every epoch.
    Params:
    model - a pytorch model to train
    optimizer - an optimizer
    criterion - the criterion (loss function)
    nepochs - number of training epochs
    train_loader - dataloader for the trainset
    val_loader - dataloader for the valset
    is_image_input (default False) - If True, flatten 2D images into a 1D array.
                                     Should be True for Neural Networks
                                     but False for Convolutional Neural Networks.
    '''
    train_losses, val_losses = [], []
    for e in range(nepochs):
        running_loss = 0.0
        running_val_loss = 0.0

        # Training loop
        model.train()  # Set model to training mode
        for images, labels in train_loader:
            if is_image_input:
                # Flatten images for Neural Networks
                images = images.view(images.size(0), -1)

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)  # Compute loss

            # Backward pass
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        # Validation loop
        model.eval()  # Set model to evaluation mode
        with torch.no_grad():
            for images, labels in val_loader:
                if is_image_input:
                    # Flatten images for Neural Networks
                    images = images.view(images.size(0), -1)

                # Forward pass
                outputs = model(images)
                val_loss = criterion(outputs, labels)
                running_val_loss += val_loss.item()

        # Track losses
        train_loss = running_loss / len(train_loader)
        val_loss = running_val_loss / len(val_loader)
        train_losses.append(train_loss)
        val_losses.append(val_loss)

        # Print progress
        print(f"Epoch: {e+1}/{nepochs}.. "
              f"Training Loss: {train_loss:.3f}.. "
              f"Validation Loss: {val_loss:.3f}")

    return train_losses, val_losses

# %%
  # 6.1. Train the model.
  ## NOTE: Do not run this cell continuously without running the two cells above!
  ##       Otherwise, you might train a model you have already trained.
  ##       So make sure to run the two cells above (to first initialize the model
  ##       and optimizer), every time, before running this cell!
train_losses, val_losses = train_model(model, optimizer, criterion, nepochs,
                                       train_loader, val_loader, is_image_input=True)
# Out:
# Epoch: 1/5.. Training Loss: 1.252.. Validation Loss: 0.818
# Epoch: 2/5.. Training Loss: 0.733.. Validation Loss: 0.707
# Epoch: 3/5.. Training Loss: 0.657.. Validation Loss: 0.649
# Epoch: 4/5.. Training Loss: 0.615.. Validation Loss: 0.619
# Epoch: 5/5.. Training Loss: 0.588.. Validation Loss: 0.605

# %% [markdown]
# If you implemented everything correctly, you should see the training loss drop with each epoch.

# %% [markdown]
# 8. Plot train loss and validation loss as a function of epoch. **On the same graph!**

# %%
# plot train and validation loss as a function of #epochs
import matplotlib.pyplot as plt

def plot_losses(train_losses, val_losses):
    '''
    Plots training and validation loss over epochs.
    '''
    epochs = range(1, len(train_losses) + 1)  # Create a range for the number of epochs

    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_losses, label='Training Loss', marker='o')  # Training loss
    plt.plot(epochs, val_losses, label='Validation Loss', marker='o')  # Validation loss

    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the function with the tracked losses
plot_losses(train_losses, val_losses)

# %% [markdown]
# With the network trained, we can check out it's predictions:

# %%
# you can run this cell multiple times for different images
random_prediction_example(mnist_dataloader, model)
# Out:
# (tensor([[2.4464e-05, 2.4464e-05, 2.4464e-05, 2.4464e-05, 7.1344e-04, 2.4464e-05,
#           2.4464e-05, 6.0512e-05, 2.4464e-05, 9.9905e-01]]),
#  9,
#  tensor(9))

# %% [markdown]
# Calculate the model's accuracy on the validation-set.

# %%
def evaluate_model(model, val_loader, is_image_input=False):
    '''
    Evaluate a model on the given dataloader.
    Params:
    model - a pytorch model to evaluate
    val_loader - dataloader for the validation set
    is_image_input (default False) - If True, flatten 2D images into a 1D array
                                     (for Neural Networks).
                                     Should be False for Convolutional Neural Networks.
    '''
    validation_accuracy = 0
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():  # Disable gradient calculations
        for images, labels in val_loader:
            if is_image_input:
                # Flatten images for Neural Networks
                images = images.view(images.size(0), -1)

            # Forward pass
            log_ps = model(images)  # Get the log probabilities
            ps = torch.exp(log_ps)  # Convert to probabilities
            top_p, top_class = ps.topk(1, dim=1)  # Get the predicted class

            # Compare predictions to true labels
            equals = top_class == labels.view(*top_class.shape)
            validation_accuracy += torch.sum(equals.type(torch.FloatTensor))

    # Normalize accuracy by dataset size
    accuracy = validation_accuracy / len(val_loader.dataset)
    return accuracy

# %%
print(f"Validation accuracy: {evaluate_model(model, val_loader, is_image_input=True)}")
# Out:
# Validation accuracy: 0.840499997138977

# %% [markdown]
# ### **5. Convolutional Neural Networks**

# %% [markdown]
# In this section, we are going to implement a convolutional neural network (CNN) and train it on the mnist dataset. It will be very similar to what you did in the previous sections but now we use new layers like ```convolution```and ```pooling```.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Reminder:
# You can go over this **[article](https://cs231n.github.io/convolutional-networks/)** to better understand convolutional neural networks.
#
# - **Convolutional operation:** A “filter”, also called a “kernel”, is passed over the image, viewing a few pixels at a time (for example, 3X3 or 5X5). The convolution operation is a dot product of the original pixel values with weights defined in the filter. The results are summed up into one number that represents all the pixels the filter observed.
#
# - **Pooling:** “Pooling” is the process of further downsampling and reducing the size of the matrix. A filter is passed over the results of the previous layer and selects one number out of each group of values (typically the maximum, this is called max pooling). This allows the network to train much faster, focusing on the most important information in each feature of the image. By sliding the window along the image, we compute the mean or the max of the portion of the image inside the window in case of MeanPooling or MaxPooling.
#
# - **Stride:** The number of pixels to pass at a time when sliding the convolutional kernel.
#
# - **Padding:** To preserve exactly the size of the input image, it is useful to add zero padding on the border of the image.

# %% [markdown]
# **Q1:** Given an image with shape [1,32,32], what will be the shape of the output of a convolution layer with 5 5x5 kernels (filters) without padding?

# %% [markdown]
# **A1:**
# <font color='red'>output shape = [5, 28, 28]
#
# using the formula:
#
# output_size = (input_size + 2*padding - kernel_size)/Stride   + 1
#
# without padding implies that padding = 0
#
# since no stride number is specified, the default for stride = 1
#
# kernel 5x5; input size 32x32
#
# output_size = (32 + 2(0) - 5)/1 + 1
#
# output_size = 28 x 28
#
# since 5 filters were applied, the channel for the output layer is 5,
#
# hence the shape
#
# output shape = [5, 28, 28]
#
#
# </font>

# %% [markdown]
# **Q2:** We would like our convolution layer to output a volume with the same shape as the input image. So input_shape and output_shape will be [1,32,32]. What should be the padding?

# %% [markdown]
# **A2:**
# <font color='red'>
# padding = 2
#
# using the formula:
#
# output_size = (input_size + 2*padding - kernel_size)/Stride + 1
#
# since output_size = input_size = 32, stride = 1, kernel = 5x5
#
# 32 = 32 -5 + 2p + 1
#
# p = 2
# </font>

# %% [markdown]
# **Q3:** Given an image with width $W_{in}$, height $H_{in}$, and a convolution layer with padding $P$, stride $S$ and filter size $F$. Write a formula for the width $W_{out}$ and a formula for the height $H_{out}$ of the convolution's output.
# (In other words, what will be the width and the height of the output?).

# %% [markdown]
# **A3:**
# <font color='red'>
# 𝑊𝑜𝑢𝑡 = (𝑊𝑖𝑛 + 2P - F)/S + 1
#
# 𝐻𝑜𝑢𝑡 = (𝐻𝑖𝑛 + 2P - F)/S +1
# </font>

# %% [markdown]
# Let's create a simple Convolutional neural network.
# The architecture:
# **Conv layer** (10 5x5 Kernels) -> **Max Pooling** (2x2 kernel) -> **Relu** -> **Conv layer** (20 5x5 Kernels) -> **Max Pooling** (2x2 kernel) -> **Relu** -> **Hidden layer** (320 units) -> **Relu** -> **Hidden layer** (50 units) -> **Output layer** (10 outputs).

# %%
class ConvolutionalNet(nn.Module):
    def __init__(self):
        super(ConvolutionalNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

        # Initialize weights
        nn.init.kaiming_normal_(self.conv1.weight)
        nn.init.kaiming_normal_(self.conv2.weight)
        nn.init.xavier_normal_(self.fc1.weight)
        nn.init.xavier_normal_(self.fc2.weight)

    def forward(self, x):
        x = self.conv1(x)
        x = F.max_pool2d(x, 2)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.max_pool2d(x, 2)
        x = F.relu(x)
        x = x.view(-1, 320)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)


cnn_model = ConvolutionalNet()
print(cnn_model)
# Out:
# ConvolutionalNet(
#   (conv1): Conv2d(1, 10, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=320, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=10, bias=True)
# )

# %% [markdown]
# We can now train the model on the train set.

# %%
# set hyperparameters
cnn_nepochs = 5
cnn_learning_rate = 0.001

# %%
# train the conv model
cnn_model = ConvolutionalNet()
# create sgd optimizer
cnn_optimizer = optim.SGD(cnn_model.parameters(), lr=cnn_learning_rate)
# create negative log likelihood loos
cnn_criterion = nn.NLLLoss()

train_losses, val_losses = train_model(cnn_model, cnn_optimizer, cnn_criterion,
                                       cnn_nepochs, train_loader, val_loader, is_image_input=False)
# Out:
# Epoch: 1/5.. Training Loss: 1.512.. Validation Loss: 0.868
# Epoch: 2/5.. Training Loss: 0.646.. Validation Loss: 0.523
# Epoch: 3/5.. Training Loss: 0.447.. Validation Loss: 0.415
# Epoch: 4/5.. Training Loss: 0.366.. Validation Loss: 0.355
# Epoch: 5/5.. Training Loss: 0.316.. Validation Loss: 0.313

# %%
# Call the function with the tracked losses
plot_losses(train_losses, val_losses)

# %%
# evaluate on the validation set
print(f"Validation accuracy: {evaluate_model(cnn_model, val_loader, is_image_input=False)}")
# Out:
# Validation accuracy: 0.909416675567627

# %% [markdown]
# You should probably see that our CNN performs better on the validation set compared to the simple neural network (within a few epochs only)

# %% [markdown]
# ___________

# %% [markdown]
# Now it's your turn: Use the code above and create a convolutional neural network that achieves the best accuracy on the validation set.
#
# You should consider changing:
# 1. Prepocess:
#   - Change normalization
#   - Better representation of the data
#
# 1. Network architecture:
#   - Number of convolutional layers
#   - Number of kernels (filters) for each convolutional layer
#   - Size of each kernel on each layer
#   - Number of hidden layers (fully connected)
#   - Number of units for each hidden layer
#   - Usage of layers like BatchNormalization and Dropout.
#   - Usage of max pooling (or maybe other pooling strategies)
#
# 1. Training hyperparameters:
#   - Learning rate
#   - Optimizer (SGD with momentum, adam, etc)
#   - Number of epochs

# %%
## Prepocess
# Define a transform to normalize the data
# Define a new transform with data augmentation and alternative normalization
new_transform = transforms.Compose([
    transforms.RandomRotation(10),  # Randomly rotate the images by up to 10 degrees
    transforms.RandomHorizontalFlip(),  # Randomly flip the images horizontally
    transforms.RandomCrop(28, padding=4),  # Randomly crop to 28x28 with padding
    transforms.ToTensor(),  # Convert images to tensors
    transforms.Normalize((0.1307,), (0.3081,))  # Dataset-specific mean and std for MNIST
])

# %%
# Apply new preprocessing to the training data
train_dataset_new = datasets.MNIST(root=data_path, train=True, download=True, transform=new_transform)

# Validation data should remain consistent with no augmentation
val_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # Keep normalization consistent
])
val_dataset_new = datasets.MNIST(root=data_path, train=False, download=True, transform=val_transform)

# Create new data loaders
train_loader_new = torch.utils.data.DataLoader(train_dataset_new, batch_size=64, shuffle=True)
val_loader_new = torch.utils.data.DataLoader(val_dataset_new, batch_size=64, shuffle=False)

# %%
def train_model_cnn(model, optimizer, criterion,
                    nepochs, train_loader, val_loader):
    """
    Train a convolutional neural network and evaluate it on validation data.

    Params:
    model - the CNN model to train.
    optimizer - optimizer for updating model weights.
    criterion - loss function (e.g., NLLLoss).
    nepochs - number of training epochs.
    train_loader - dataloader for the training set.
    val_loader - dataloader for the validation set.
    """
    train_losses, val_losses, val_accuracies = [], [], []

    for e in range(nepochs):
        running_loss = 0
        running_val_loss = 0
        correct = 0
        total = 0

        # Training Phase
        model.train()  # Set the model to training mode
        for images, labels in train_loader:

            # Move data to GPU if available
            images, labels = images.to(device), labels.to(device)

            # Clear previous gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)

            # Backward pass and optimizer step
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        # Validation Phase
        model.eval()  # Set the model to evaluation mode
        with torch.no_grad():  # Disable gradient calculations for validation
            for images, labels in val_loader:
                # Move data to GPU if available
                images, labels = images.to(device), labels.to(device)

                # Forward pass
                outputs = model(images)
                val_loss = criterion(outputs, labels)
                running_val_loss += val_loss.item()

                # Calculate validation accuracy
                _, predicted = torch.max(outputs, 1)  # Get predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        # Compute average loss and accuracy
        train_loss_avg = running_loss / len(train_loader)
        val_loss_avg = running_val_loss / len(val_loader)
        val_accuracy = 100 * correct / total

        train_losses.append(train_loss_avg)
        val_losses.append(val_loss_avg)
        val_accuracies.append(val_accuracy)

        # Print epoch statistics
        print(f"Epoch: {e+1}/{nepochs}.. ",
              f"Training Loss: {train_loss_avg:.3f}.. ",
              f"Validation Loss: {val_loss_avg:.3f}.. ",
              f"Validation Accuracy: {val_accuracy:.2f}%")

    return train_losses, val_losses, val_accuracies

# %%
## Find network and hyperparams that achieve best validation accuracy as possible

class ImprovedCNN(nn.Module):
    def __init__(self):
        super(ImprovedCNN, self).__init__()
        # Initial Convolution Layers
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)  # Conv Layer 1
        self.bn1 = nn.BatchNorm2d(32)  # Batch Normalization
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # Conv Layer 2
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)  # Conv Layer 3
        self.bn3 = nn.BatchNorm2d(128)

        # Added Convolution Layers
        self.conv4 = nn.Conv2d(128, 256, kernel_size=3, padding=1)  # Conv Layer 4
        self.bn4 = nn.BatchNorm2d(256)
        self.conv5 = nn.Conv2d(256, 512, kernel_size=3, padding=1)  # Conv Layer 5
        self.bn5 = nn.BatchNorm2d(512)

        # Fully Connected Layers
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))  # Global Average Pooling
        self.fc1 = nn.Linear(512, 256)  # Fully Connected Layer 1
        self.fc2 = nn.Linear(256, 128)  # Fully Connected Layer 2
        self.fc3 = nn.Linear(128, 10)  # Output Layer

        self.dropout = nn.Dropout(0.5)  # Dropout

    def forward(self, x):
    # Initial Convolution Layers
        x = F.relu(self.bn1(self.conv1(x)))  # Conv1 + ReLU
        x = F.max_pool2d(x, 2)  # Max Pooling (reduces by half)
        x = F.relu(self.bn2(self.conv2(x)))  # Conv2 + ReLU
        x = F.max_pool2d(x, 2)  # Max Pooling (reduces by half)
        x = F.relu(self.bn3(self.conv3(x)))  # Conv3 + ReLU
        x = F.max_pool2d(x, 2)  # Max Pooling (reduces by half)

        # Added Convolution Layers
        x = F.relu(self.bn4(self.conv4(x)))  # Conv4 + ReLU
        # Remove pooling here to avoid feature map shrinking too much
        x = F.relu(self.bn5(self.conv5(x)))  # Conv5 + ReLU

        # Global Average Pooling
        x = self.global_avg_pool(x)  # Adaptive Average Pooling to (1x1)
        x = x.view(x.size(0), -1)  # Flatten

        # Fully Connected Layers
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)

        return F.log_softmax(x, dim=1)

# %%
## Training your hyperparameter

# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Instantiate the model and move it to GPU if available
cnn_model_new = ImprovedCNN()
cnn_model_new = cnn_model_new.to(device)

# Define optimizer and loss function
optimizer = optim.Adam(cnn_model_new.parameters(), lr=0.001)
criterion = nn.NLLLoss()

# Train the model
train_losses, val_losses, val_accuracies = train_model_cnn(
    model=cnn_model_new,
    optimizer=optimizer,
    criterion=criterion,
    nepochs=20,
    train_loader=train_loader_new,
    val_loader=val_loader_new
)
# Out:
# Epoch: 1/20..  Training Loss: 0.485..  Validation Loss: 0.288..  Validation Accuracy: 91.61%
# Epoch: 2/20..  Training Loss: 0.194..  Validation Loss: 0.113..  Validation Accuracy: 96.38%
# Epoch: 3/20..  Training Loss: 0.152..  Validation Loss: 0.061..  Validation Accuracy: 98.15%
# Epoch: 4/20..  Training Loss: 0.133..  Validation Loss: 0.065..  Validation Accuracy: 97.92%
# Epoch: 5/20..  Training Loss: 0.121..  Validation Loss: 0.051..  Validation Accuracy: 98.50%
# Epoch: 6/20..  Training Loss: 0.110..  Validation Loss: 0.062..  Validation Accuracy: 98.10%
# Epoch: 7/20..  Training Loss: 0.104..  Validation Loss: 0.071..  Validation Accuracy: 97.82%
# Epoch: 8/20..  Training Loss: 0.100..  Validation Loss: 0.049..  Validation Accuracy: 98.60%
# Epoch: 9/20..  Training Loss: 0.093..  Validation Loss: 0.053..  Validation Accuracy: 98.40%
# Epoch: 10/20..  Training Loss: 0.085..  Validation Loss: 0.052..  Validation Accuracy: 98.40%
# Epoch: 11/20..  Training Loss: 0.084..  Validation Loss: 0.041..  Validation Accuracy: 98.70%
# Epoch: 12/20..  Training Loss: 0.085..  Validation Loss: 0.069..  Validation Accuracy: 98.24%
# Epoch: 13/20..  Training Loss: 0.079..  Validation Loss: 0.044..  Validation Accuracy: 98.66%
# Epoch: 14/20..  Training Loss: 0.079..  Validation Loss: 0.048..  Validation Accuracy: 98.52%
# Epoch: 15/20..  Training Loss: 0.075..  Validation Loss: 0.041..  Validation Accuracy: 98.82%
# Epoch: 16/20..  Training Loss: 0.070..  Validation Loss: 0.042..  Validation Accuracy: 98.66%
# Epoch: 17/20..  Training Loss: 0.072..  Validation Loss: 0.035..  Validation Accuracy: 98.92%
# Epoch: 18/20..  Training Loss: 0.068..  Validation Loss: 0.042..  Validation Accuracy: 98.61%
# Epoch: 19/20..  Training Loss: 0.065..  Validation Loss: 0.097..  Validation Accuracy: 97.74%
# Epoch: 20/20..  Training Loss: 0.066..  Validation Loss: 0.045..  Validation Accuracy: 98.53%

# %%
def evaluate_model_cnn(model, criterion, val_loader):
    """
    Evaluate a convolutional neural network on validation data.

    Params:
    model - the CNN model to evaluate.
    criterion - loss function (e.g., NLLLoss).
    val_loader - dataloader for the validation set.
    """
    running_val_loss = 0
    correct = 0
    total = 0

    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():  # Disable gradient calculations for validation
        for images, labels in val_loader:
            # Move data to GPU if available
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            val_loss = criterion(outputs, labels)
            running_val_loss += val_loss.item()

            # Calculate validation accuracy
            _, predicted = torch.max(outputs, 1)  # Get predictions
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    # Compute average loss and accuracy
    val_loss_avg = running_val_loss / len(val_loader)
    val_accuracy = 100 * correct / total

    print(f"Overall Validation Loss: {val_loss_avg:.3f}")
    print(f"Overall Validation Accuracy: {val_accuracy:.2f}%")
    return val_loss_avg, val_accuracy

# %%
# Get the overall validation accuracy
overall_val_loss, overall_val_accuracy = evaluate_model_cnn(
    model=cnn_model_new,
    criterion=criterion,
    val_loader=val_loader_new
)

print(f"Final Validation Accuracy: {overall_val_accuracy:.2f}%")
# Out:
# Overall Validation Loss: 0.045
# Overall Validation Accuracy: 98.53%
# Final Validation Accuracy: 98.53%

# %%
# Plot Losses and Accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Training Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(val_accuracies, label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.legend()

plt.show()

# %%
#   Function to save the best model in this variable
def save_model(model, filepath="trained_model.pth"):
    """
    Save the trained model to a file.

    Params:
    model - the trained PyTorch model.
    filepath - the file path to save the model.
    """
    torch.save(model.state_dict(), filepath)
    print(f"Model saved to {filepath}")

# %%
#Call the function to save the model

save_model(cnn_model_new, filepath="/content/Assignment5/cnn_trained_model2.pth")
# Out:
# Model saved to /content/Assignment5/cnn_trained_model2.pth

# %% [markdown]
# When you are satisfied with your model performance on the validation set, load the [test set](https://drive.google.com/file/d/1GFtLV1aNo49IDdObyyvZoTS4w_qEZvjM/view?usp=share_link) (the samples are already normalized), and write the model predictions for each test sample to a file called "predictions.txt". You can use the code below.
#
#
# **Upload the file to the Moodle system with this notebook.**
#
# Make sure that each prediction will be printed in a new line.
#
# For Example ("predictions.txt"):
# ```
# 0
# 5
# 9
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Navigate to a specific folder
folder_path = '/content/drive/My Drive/Machine_learning_Intro_Assignment'
os.chdir(folder_path)

# Verify current working directory
print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/drive/My Drive/Machine_learning_Intro_Assignment

# %%
def predict_and_save(model, test_path, file_name):
    # Load mnist test data
    mnist_test_data = torch.utils.data.TensorDataset(torch.load(test_path))
    # Create a dataloader
    mnist_test_loader = torch.utils.data.DataLoader(mnist_test_data, batch_size=32, shuffle=False)

    # Get the device of the model
    device = next(model.parameters()).device

    # Make predictions for each batch and save all predictions in total_preds
    total_preds = torch.empty(0, dtype=torch.long, device=device)
    for imgs in mnist_test_loader:
        # Move input data to the same device as the model
        inputs = imgs[0].to(device)

        log_ps = model(inputs)
        ps = torch.exp(log_ps)
        _, top_class = ps.topk(1, dim=1)
        total_preds = torch.cat((total_preds, top_class.reshape(-1)))

    total_preds = total_preds.cpu().numpy()  # Move predictions to CPU for saving

    # Write all predictions to a file
    with open(file_name, "w") as pred_f:
        for pred in total_preds:
            pred_f.write(str(pred) + "\n")

# %%
# Ensure the model is on the GPU (or CPU if GPU is unavailable)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_model = ImprovedCNN()  # Define your model architecture
best_model.load_state_dict(torch.load("/content/Assignment5/cnn_trained_model2.pth"))  # Load the trained weights
best_model.to(device)  # Move model to the correct device
best_model.eval()  # Set model to evaluation mode
# Out:
# <ipython-input-91-5ac3bae9f402>:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_model.load_state_dict(torch.load("/content/Assignment5/cnn_trained_model2.pth"))  # Load the trained weights
# ImprovedCNN(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (global_avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc1): Linear(in_features=512, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# run this to save test predictions to "predictions.txt"
predict_and_save(model = best_model, test_path="/content/Assignment5/mnist_test.pth", file_name="/content/Assignment5/predictions3.txt")
# Out:
# <ipython-input-90-9c6b0915e9bb>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   mnist_test_data = torch.utils.data.TensorDataset(torch.load(test_path))

# %%
import os

# Verify if the test data file exists
test_path = "/content/Assignment5/mnist_test.pth"
print("Test data exists:", os.path.exists(test_path))
# Out:
# Test data exists: True

# %%
# Path to your .pth file
test_data_path = "/content/Assignment5/mnist_test.pth"

# Load the test data
test_data = torch.load(test_data_path)
# Out:
# <ipython-input-60-d83532f10844>:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_data = torch.load(test_data_path)

# %%
##a little checking of the test data
import matplotlib.pyplot as plt

# Extract the first image tensor
sample_image = test_data[13]  # Adjust indexing based on your data structure

# If the sample image is a tensor, convert it to a NumPy array for visualization
if isinstance(sample_image, torch.Tensor):
    sample_image = sample_image.numpy()

# Plot the image
plt.imshow(sample_image.squeeze(), cmap='gray')  # Use cmap='gray' for grayscale images
plt.title("Sample Test Image")
plt.axis('off')
plt.show()
